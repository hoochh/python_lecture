# %% [markdown]
# # [과제]yes24 도서 웹 크롤링
# 1. 책 키워드 입력해서 url 구성
#
# 2. 스크래핑 내용
# - 제목, 저자, 출판사, 출판일, 가격, 평점(정적 or 동적)
# - 페이지 이동해서 계속해서 반복 스크래핑(동적)
# - 이미지 다운로드
#
# 3. DataFrame으로 작성해서 csv 파일로 저장
#
# 4. mysql DB에 저장

# %%
import urllib.request as req1
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pymysql

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# %%
urld="http://www.yes24.com/Product/Search?domain=ALL&query=%EC%8B%9D%EB%AC%BC%ED%95%99&page=1"
driver=webdriver.Chrome('chromedriver')
driver.implicitly_wait(5)
driver.get(urld)
time.sleep(2)

# %%
def image_save(res,i):
    save_name='data/book_images/image'+str(i)+'.jpg'
    req1.urlretrieve(res,save_name)
    print(save_name,'가 저장됨')

# %%
url="http://www.yes24.com/Product/Search?domain=ALL&query=%EC%8B%9D%EB%AC%BC%ED%95%99&page="
j=1

book_list=[]
i=0
stopFlag=False
flag=True

for n in range(2,11):
    res=req1.urlopen(url+str(j))
    bs=BeautifulSoup(res,'html.parser')
    books=bs.select('#yesSchList > li')

    for book in books:
        title=book.select('div > div.item_info > div.info_row.info_name > a.gd_name')
        author=book.select('div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_auth')
        publisher=book.select('div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_pub > a')
        date=book.select('div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_date')
        price=book.select('div > div.item_info > div.info_row.info_price > strong > em')
        rating=book.select('div > div.item_info > div.info_row.info_rating > span.rating_grade > em')

        if title == []:
            title='X'
        else:
            title=title[0].text

        if author == []:
            author='X'
        else:
            author=author[0].text.replace("\n","").replace("\r","").replace("  ","")

        if publisher == []:
            publisher='X'
        else:
            publisher=publisher[0].text

        if date == []:
            date='X'
        else:
            date=date[0].text

        if price == []:
            price='X'
        else:
            price=price[0].text

        if rating == []:
            rating='X'
        else:
            rating=rating[0].text

        b_list=(title,author,publisher,date,price,rating)
        print(b_list)

        # 상품 이미지 저장
        i+=1
        img=book.select('div > div.item_img > div.img_canvas > span > span > a > em > img')
        img_src=img[0]['data-original']
        image_save(img_src,i)

        # book_list에 추가
        book_list.append(b_list)

    book_count=len(driver.find_elements(By.CSS_SELECTOR, '#yesSchList > li'))
    j+=1
    if book_count<24:
        driver.get(url)
        driver.quit()
        flag=False
    else:
        linkurl='#goodsListWrap > div.sGoodsPagen > div > a:nth-child(%d)'%n

        if bs.select(linkurl)!=[]:
            linkNum=driver.find_element(By.CSS_SELECTOR, linkurl)
            linkNum.click()
            time.sleep(2)
        else:
            driver.get(url)
            driver.quit()
            # flag=False

if flag!=False:
    nextblock='#goodsListWrap > div.sGoodsPagen > div > a.bgYUI.next'
    nextNum=driver.find_element(By.CSS_SELECTOR,nextblock)
    nextNum.click()
    time.sleep(2)

while flag:
    for n in range(4,13):
        res=req1.urlopen(url+str(j))
        bs=BeautifulSoup(res,'html.parser')
        books=bs.select('#yesSchList > li')
        for book in books:
            title=book.select('div > div.item_info > div.info_row.info_name > a.gd_name')
            author=book.select('div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_auth')
            publisher=book.select('div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_pub > a')
            date=book.select('div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_date')
            price=book.select('div > div.item_info > div.info_row.info_price > strong > em')
            rating=book.select('div > div.item_info > div.info_row.info_rating > span.rating_grade > em')
            
                        
            if title == []:
                title='X'
            else:
                title=title[0].text
                
            if author == []:
                author='X'
            else:
                author=author[0].text.replace("\n","").replace("\r","").replace("  ","")
                
            if publisher == []:
                publisher='X'
            else:
                publisher=publisher[0].text
                
            if date == []:
                date='X'
            else:
                date=date[0].text
                
            if price == []:
                price='X'
            else:
                price=price[0].text
                
            if rating == []:
                rating='X'
            else:
                rating=rating[0].text
                
            b_list=(title,author,publisher,date,price,rating)
            
            # 상품 이미지 저장
            i+=1
            img=book.select('div > div.item_img > div.img_canvas > span > span > a > em > img')
            img_src=img[0]['data-original']
            image_save(img_src,i)

            # book_list에 추가
            book_list.append(b_list)
            print(b_list)

        book_count=len(driver.find_elements(By.CSS_SELECTOR, '#yesSchList > li'))
        j+=1
        
        linkurl='#goodsListWrap > div.sGoodsPagen > div > a:nth-child(%d)'%n
        linkNum=driver.find_element(By.CSS_SELECTOR, linkurl)
        linkNum.click()
        time.sleep(2)
    
        if book_count<24:
            stopFlag=True
            break
    if stopFlag==True:
        break
        
    nextblock='#goodsListWrap > div.sGoodsPagen > div > a.bgYUI.next'
    nextNum=driver.find_element(By.CSS_SELECTOR,nextblock)
    nextNum.click()
    time.sleep(2)
    
    # 다음 블록 첫 번째 페이지
    res=req1.urlopen(url+str(j))
    bs=BeautifulSoup(res,'html.parser')
    books=bs.select('#yesSchList > li')
    
    for book in books:
        title=book.select('div > div.item_info > div.info_row.info_name > a.gd_name')
        author=book.select('div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_auth')
        publisher=book.select('div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_pub > a')
        date=book.select('div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_date')
        price=book.select('div > div.item_info > div.info_row.info_price > strong > em')
        rating=book.select('div > div.item_info > div.info_row.info_rating > span.rating_grade > em')

        if title == []:
            title='X'
        else:
            title=title[0].text

        if author == []:
            author='X'
        else:
            author=author[0].text.replace("\n","").replace("\r","").replace("  ","")

        if publisher == []:
            publisher='X'
        else:
            publisher=publisher[0].text

        if date == []:
            date='X'
        else:
            date=date[0].text

        if price == []:
            price='X'
        else:
            price=price[0].text

        if rating == []:
            rating='X'
        else:
            rating=rating[0].text

        b_list=(title,author,publisher,date,price,rating)
        print(b_list)
            
        # book_list에 추가
        book_list.append(b_list)

        # 상품 이미지 저장
        i+=1
        img=book.select('div > div.item_img > div.img_canvas > span > span > a > em > img')
        img_src=img[0]['data-original']
        image_save(img_src,i)

    book_count=len(driver.find_elements(By.CSS_SELECTOR, '#yesSchList > li'))
    j+=1
    if book_count<24:
        stopFlag=True
        break
        
    linkurl='#goodsListWrap > div.sGoodsPagen > div > a:nth-child(4)'
    linkNum=driver.find_element(By.CSS_SELECTOR, linkurl)
    linkNum.click()
    time.sleep(2)

if flag!=False:
    driver.get(url)
    driver.quit()
# Out:
# ('식물학자의 노트', '신혜우 글그림', '김영사', '2021년 04월', '17,820', '9.8')
# data/book_images/image1.jpg 가 저장됨
# ('가드닝을 위한 식물학', '제프 호지 저 / 김정은 역', '따비', '2021년 11월', '19,800', 'X')
# data/book_images/image2.jpg 가 저장됨
# ('이일하 교수의 식물학 산책', '이일하 저', '궁리출판', '2022년 05월', '19,800', 'X')
# data/book_images/image3.jpg 가 저장됨
# ('재밌어서 밤새 읽는 식물학 이야기', '이나가키 히데히로 저/박현아 역/류충민 감수', '더숲', '2019년 08월', '10,800', '9.3')
# data/book_images/image4.jpg 가 저장됨
# ('식물학자의 노트 (큰글자책)', '신혜우 글그림', '김영사', '2021년 09월', '22,000', '10.0')
# data/book_images/image5.jpg 가 저장됨
# ('식물학 수업', '이나가키 히데히로 저/장은정 역', '키라북스', '2021년 02월', '13,050', '10.0')
# data/book_images/image6.jpg 가 저장됨
# ('시체를 보는 식물학자', '마크 스펜서 저/김성훈 역', '더퀘스트', '2021년 10월', '14,400', '9.5')
# data/book_images/image7.jpg 가 저장됨
# ('見てびっくり野菜の植物學', '盛口 滿 저.그림', '少年寫眞新聞社', '2012년 02월', '23,390', 'X')
# data/book_images/image8.jpg 가 저장됨
# ('식물학자의 정원 산책', '레나토 브루니 저/장혜경 역', '초사흘달', '2020년 07월', '16,200', '9.7')
# data/book_images/image9.jpg 가 저장됨
# ('자원식물학', '류수노, 이봉호, 이병윤 공저', '한국방송통신대학교출판문화원', '2018년 01월', '26,600', 'X')
# data/book_images/image10.jpg 가 저장됨
# ('컨테이너에 들어간 식물학자', '최성화 저', '바이오스펙테이터', '2019년 12월', '9,000', 'X')
# data/book_images/image11.jpg 가 저장됨
# ('최신조경식물학', '김용식 저', '광일문화사', '2018년 02월', '32,000', 'X')
# data/book_images/image12.jpg 가 저장됨
# ('사고 일반식물학', '임경빈 등저', '향문사', '2000년 01월', '33,000', '6.0')
# data/book_images/image13.jpg 가 저장됨
# ('술 취한 식물학자', '에이미 스튜어트 저 / 구계원 역', '문학동네', '2016년 08월', '20,700', '8.6')
# data/book_images/image14.jpg 가 저장됨
# ('자원식물학', '류수노, 이봉호, 이병윤 공저', '한국방송통신대학교출판문화원', '2018년 02월', '23,000', 'X')
# data/book_images/image15.jpg 가 저장됨
# ('어린이를 위한 식물학', '지니 K. 풀브라이트 글 / 명지대학교 창조과학연구소 역', '꿈을이루는사람들', '2014년 07월', '22,500', '10.0')
# data/book_images/image16.jpg 가 저장됨
# ('식물학', 'James D. Mauseth 저', '월드사이언스', '2019년 02월', '42,000', 'X')
# data/book_images/image17.jpg 가 저장됨
# ('베란다 식물학', '이완주 저', '지오북', '2012년 05월', '13,500', '8.0')
# data/book_images/image18.jpg 가 저장됨
# ('식물학 수업', '이나가키 히데히로 저/장은정 역', '키라북스', '2021년 02월', '10,000', 'X')
# data/book_images/image19.jpg 가 저장됨
# ('약용 식물학 ', '채영암 /김성민', '향문사', '2007년 01월', '33,000', 'X')
# data/book_images/image20.jpg 가 저장됨
# ('식물학', 'James E. Bidlack, Shelley H. Jansky 공저 / 김성하, 강혜순 등역', '라이프사이언스', '2014년 03월', '38,000', 'X')
# data/book_images/image21.jpg 가 저장됨
# ('응용 식물학', '한태진 저', '월드사이언스', '2011년 08월', '18,000', 'X')
# data/book_images/image22.jpg 가 저장됨
# ('한약자원 식물학', '장상문 등저', '학문출판사', '1996년 04월', '33,250', 'X')
# data/book_images/image23.jpg 가 저장됨
# ('자원식물학', '강병화 외', '향문사', '2009년 03월', '42,000', 'X')
# data/book_images/image24.jpg 가 저장됨
# ('관상식물학', '안영희 저', '태림문화사', '2010년 03월', '32,000', 'X')
# data/book_images/image25.jpg 가 저장됨
# ('약용식물학', '나호정, 박진한, 임종필, 최인영, 홍승헌 공저', '신일(신일북스)', '2007년 09월', '9,000', 'X')
# data/book_images/image26.jpg 가 저장됨
# ('자원식물학개론', '안상득', '선진문화사', '1996년 02월', '16,000', 'X')
# data/book_images/image27.jpg 가 저장됨
# ('약용자원식물학', '주영승', '영림사', '2005년 03월', '35,000', 'X')
# data/book_images/image28.jpg 가 저장됨
# ('식물학ㆍ재배학 동양의학ㆍ식품학 용어해설 ', '강병화 등저', '한국학술정보', '2012년 06월', '72,000', 'X')
# data/book_images/image29.jpg 가 저장됨
# ('원예 자원식물학', '박석근, 정미나 공저', '이담북스(이담Books)', '2012년 02월', '19,800', 'X')
# data/book_images/image30.jpg 가 저장됨
# ('자원식물학', 'BERL B. SIMPSON, MOLLY C. OGORZALY 공저 / 박기룡, 홍석표, 김무열 공역', '교보문고', '2011년 03월', '33,000', 'X')
# data/book_images/image31.jpg 가 저장됨
# ('민족전통식물학', '김현 저', '월드사이언스', '2008년 09월', '20,000', 'X')
# data/book_images/image32.jpg 가 저장됨
# ('우리의 고전과 옛 교과서 629책. 148 식물학(중)교과서 식물학(중)교과서 부도', '참빛아카이브 저', '한국학술정보', '2021년 10월', '42,000', 'X')
# data/book_images/image33.jpg 가 저장됨
# ('우리의 고전과 옛 교과서 629책. 455 중등식물학', '참빛아카이브 저', '한국학술정보', '2021년 10월', '25,000', 'X')
# data/book_images/image34.jpg 가 저장됨
# ('해산식물학', 'Glinton J. Dawes 저 오윤식 역저', '월드사이언스', '2006년 03월', '30,000', 'X')
# data/book_images/image35.jpg 가 저장됨
# ('자원식물의 이용을 위한 식물학·재배학·동양의학·식품학 용어 해설', '강병화 등저', '한국학술정보', '2016년 05월', '48,000', 'X')
# data/book_images/image36.jpg 가 저장됨
# ('원예자원식물학', '박석근, 정미나 공저', '이담북스(이담Books)', '2016년 05월', '13,200', 'X')
# data/book_images/image37.jpg 가 저장됨
# ('한방식용식물학', '고성권 저', '진영사(박진영)', '2016년 04월', '16,000', 'X')
# data/book_images/image38.jpg 가 저장됨
# ('식물학자의 식탁', '스쥔 저/류춘톈 그림/박소정 역', '현대지성', '2019년 06월', '15,750', '9.2')
# data/book_images/image39.jpg 가 저장됨
# ('식물학자의 식탁', '스쥔 저/류춘톈 그림/박소정 역', '현대지성', '2019년 06월', '12,000', 'X')
# data/book_images/image40.jpg 가 저장됨
# ('시체를 보는 식물학자', '마크 스펜서 저', '길벗', '2021년 11월', '12,800', '10.0')
# data/book_images/image41.jpg 가 저장됨
# ('식물학자 윤경은 교수와  우리집 정원 만들기', '윤경은 저', '김영사', '2007년 04월', '13,500', '8.0')
# data/book_images/image42.jpg 가 저장됨
# ('술 취한 식물학자', '에이미 스튜어트 저 / 구계원 역', '문학동네', '2016년 11월', '17,300', 'X')
# data/book_images/image43.jpg 가 저장됨
# ('[너울나비]직업페이퍼토이 12탄 _ 식물학자, 아쿠아리스트, 곤충학자, 사육사', '너울나비,페이퍼토이,종이만들기,키덜트', '너울나비', 'X', '10,000', 'X')
# data/book_images/image44.jpg 가 저장됨
# ('[너울나비]직업페이퍼토이 12탄 _ 식물학자, 아쿠아리스트, 곤충학자, 사육사', '너울나비,페이퍼토이,종이만들기,키덜트', '너울나비', 'X', '10,000', 'X')
# data/book_images/image45.jpg 가 저장됨
# ('식물학자가 본 성경속의 식물 ', '윤의수 글사진', '진솔', '2017년 07월', '30,000', 'X')
# data/book_images/image46.jpg 가 저장됨
# ('식물조직배양의 생물학', '강영희 등역', '지구문화사', '2000년 01월', '12,000', 'X')
# data/book_images/image47.jpg 가 저장됨
# ('식물학자 윤정은 교수의 우리집 용기정원 만들기', '윤경은 저', '김영사', '2008년 02월', '12,600', '7.5')
# data/book_images/image48.jpg 가 저장됨
# ('직업페이퍼토이 12탄_식물학자, 아쿠아리스트, 곤충학자, 사육사 DIY만들기', 'X', 'X', 'X', '11,000', 'X')
# data/book_images/image49.jpg 가 저장됨
# ('식물학자의 딸', '감독 : 다이 시지에/출연 : 밀레느 잠파노이,이소염', '시네하우스', '2018년 01월', '19,800', 'X')
# data/book_images/image50.jpg 가 저장됨
# ('식물학자의 정원 산책', '레나토 브루니 저/장혜경 역', '초사흘달', '2020년 07월', '12,600', 'X')
# data/book_images/image51.jpg 가 저장됨
# ('식물학자의 식탁 (큰글자책) ', '스쥔 저/류춘톈 그림/박소정 역', '현대지성', '2020년 06월', '35,000', 'X')
# data/book_images/image52.jpg 가 저장됨
# ('식물전능성의 분자생물학', '구령목', '지구문화사', '1997년 03월', '12,000', 'X')
# data/book_images/image53.jpg 가 저장됨
# ('食物學   1 第2版', '日本フ-ドスペシャリ 저', '建帛社', '2021년 03월', '28,590', 'X')
# data/book_images/image54.jpg 가 저장됨
# ('食物學   1－食品の成分と機能－', '日本フ-ドスペシャリ 저', '建帛社', '2017년 09월', '28,590', 'X')
# data/book_images/image55.jpg 가 저장됨
# ('ボタニカルイラストで見る園芸植物學百科', 'G.ホッジ 저上原 ゆうこ 역', '原書房', '2015년 06월', '36,390', 'X')
# data/book_images/image56.jpg 가 저장됨
# ('觀察する目が變わる植物學入門', '矢野興一 저', 'ベレ出版', '2012년 05월', '22,090', 'X')
# data/book_images/image57.jpg 가 저장됨
# ('新しい食物學 食生活と健康を考える', '加藤陽治 / 編集 長沼誠子 / 編集 저', '南江堂', '2010년 04월', '23,390', 'X')
# data/book_images/image58.jpg 가 저장됨
# ('植物學ラテン語辭典', '豊國秀夫 편', 'ぎょうせい', '2009년 09월', '140,370', 'X')
# data/book_images/image59.jpg 가 저장됨
# ('食物學2 食品材料と加工，貯藏.流通技術', '日本フ-ドスペシャリ 저', '建帛社', '2017년 09월', '28,590', 'X')
# data/book_images/image60.jpg 가 저장됨
# ('食物學槪論 第2版', '藤原 葉子 編著 저', '光生館', '2017년 09월', '23,390', 'X')
# data/book_images/image61.jpg 가 저장됨
# ('怖くて眠れなくなる植物學', '稻垣 榮洋 저', 'PHP硏究所', '2022년 02월', '9,610', 'X')
# data/book_images/image62.jpg 가 저장됨
# ('怖くて眠れなくなる植物學', '이나가키 히데히로 저', 'PHPエディタ', '2017년 07월', '18,190', 'X')
# data/book_images/image63.jpg 가 저장됨
# ('アフロ.ユ-ラシアの考古植物學', '庄田 愼矢 저', 'クバプロ', '2019년 05월', '41,590', 'X')
# data/book_images/image64.jpg 가 저장됨
# ('南島植物學,民俗學の泰斗 田代安定', '名越 護 저', '南方新社', '2017년 03월', '36,390', 'X')
# data/book_images/image65.jpg 가 저장됨
# ('面白くて眠れなくなる植物學', '稻垣 榮洋 저', 'PHP硏究所', '2021년 02월', '9,610', 'X')
# data/book_images/image66.jpg 가 저장됨
# ('オックスフォ-ド 植物學辭典 新裝版', '駒嶺 穆 監譯 M.アラビ- 편', '朝倉書店', '2021년 09월', '140,370', 'X')
# data/book_images/image67.jpg 가 저장됨
# ('ボタニスト パリの標本館を築いた植物學者', 'M.ジャンソン 저C.フォ-ヴ 편', 'タイプショップ', '2020년 10월', '23,390', 'X')
# data/book_images/image68.jpg 가 저장됨
# ('植物のたくらみ 香りと色の植物學', '有村 源一郞 저西原 昌宏 저', 'ベレ出版', '2018년 04월', '19,490', 'X')
# data/book_images/image69.jpg 가 저장됨
# ('面白くて眠れなくなる植物學', '이나가키 히데히로 저', 'PHPエディタ', '2016년 05월', '16,890', 'X')
# data/book_images/image70.jpg 가 저장됨
# ('生藥單 改訂第3版~語源から覺える植物學', '伊藤 美千穗 감수北山 隆 감수', '丸善雄松堂', '2017년 12월', '49,390', 'X')
# data/book_images/image71.jpg 가 저장됨
# ('植物學「超」入門 ', '다나카 오사무 저', 'SBクリエイテ', '2016년 03월', '14,290', 'X')
# data/book_images/image72.jpg 가 저장됨
# ('藥用植物學 改訂第7版', '水野 瑞夫 감수,木村 孟淳 他編集', '南江堂', '2013년 08월', '40,000', 'X')
# data/book_images/image73.jpg 가 저장됨
# ('牧野富太郞 日本植物學の父', '淸水 洋美 文 里美 和彦 繪 저', '汐文社', '2020년 07월', '20,790', 'X')
# data/book_images/image74.jpg 가 저장됨
# ('食卓を變えた植物學者', 'D.スト-ン 저三木 直子 역', '築地書館', '2021년 04월', '37,690', 'X')
# data/book_images/image75.jpg 가 저장됨
# ('식물 학습 도감 ', '윤주복 저', '진선아이', '2013년 10월', '37,800', '9.6')
# data/book_images/image76.jpg 가 저장됨
# ('식물 학교에 오세요!', '김성화, 권수진 공저 / 이민하 그림', '북멘토', '2006년 12월', '6,300', '10.0')
# data/book_images/image77.jpg 가 저장됨
# ('접이식 물통(지름9.5cm)/어린이날선물 학원판촉', 'X', 'X', 'X', '4,070', 'X')
# data/book_images/image78.jpg 가 저장됨
# ('동물이랑 식물이 같다고요?!', '노정임 글/안경자 그림/이정모 감수', '현암사', '2013년 02월', '11,700', 'X')
# data/book_images/image79.jpg 가 저장됨
# ('커다란 나무 같은 사람', '이세 히데코 글그림', '청어람미디어', '2010년 05월', '9,900', '9.6')
# data/book_images/image80.jpg 가 저장됨
# ('꽃은 알고 있다', '퍼트리샤 윌트셔 저/김아림 역', '웅진지식하우스', '2019년 12월', '14,850', '9.6')
# data/book_images/image81.jpg 가 저장됨
# ('The Drunken Botanist', 'Amy Stewart', 'Timber Press', '2013년 05월', '30,750', 'X')
# data/book_images/image82.jpg 가 저장됨
# ('Murder Most Florid', '마크 스펜서 저', 'QUADRILLE', '2019년 11월', '27,510', 'X')
# data/book_images/image83.jpg 가 저장됨
# ('The Drunken Botanist', 'Amy Stewart,Coleen Marlo (NRT)', 'Highbridge Company', '2013년 03월', '55,040', 'X')
# data/book_images/image84.jpg 가 저장됨
# ("The Drunken Botanist: The Plants That Create the World's Great Drinks", 'Amy Stewart', 'Algonquin Books of Chapel Hill', '2013년 03월', '32,210', 'X')
# data/book_images/image85.jpg 가 저장됨
# ('식물이라는 우주', '안희경 저', '시공사', '2021년 03월', '20,700', '9.4')
# data/book_images/image86.jpg 가 저장됨
# ('사계절 꽃 종이접기 산책', '마블 플래닝 저', '혜지원', '2021년 07월', '10,800', 'X')
# data/book_images/image87.jpg 가 저장됨
# ('그 산 그 꽃', '유기억 저', '황소걸음', '2022년 04월', '15,000', '9.2')
# data/book_images/image88.jpg 가 저장됨
# ('식물과학 Online ', '이유성 편저', '우성문화사', '2006년 08월', '25,000', 'X')
# data/book_images/image89.jpg 가 저장됨
# ('[멜리사앤더그] 꽃 모양 돋보기', '멜리사앤더그, 돋보기, 식물학습', '멜리사앤더그', 'X', '15,000', 'X')
# data/book_images/image90.jpg 가 저장됨
# ('[멜리사앤더그] 꽃 모양 돋보기', '멜리사앤더그, 돋보기, 식물학습', '멜리사앤더그', 'X', '15,000', 'X')
# data/book_images/image91.jpg 가 저장됨
# ('일상 속 숨어 있는 생물학 이야기', '사마키 다케오, 아오노 히로유키 편저/김정환 역', '예문아카이브', '2021년 09월', '11,700', '9.7')
# data/book_images/image92.jpg 가 저장됨
# ('식물이라는 우주', '안희경 저', '시공사', '2021년 04월', '16,000', 'X')
# data/book_images/image93.jpg 가 저장됨
# ('보따니스트', '마르 장송, 샤를로트 포브 저/박태신 역/정수영 감수', '도서출판가지', '2021년 09월', '16,200', '9.0')
# data/book_images/image94.jpg 가 저장됨
# ('생명 곁에 앉아 있는 죽음', '이나가키 히데히로 저/노만수 역', '살림출판사', '2020년 09월', '13,500', '10.0')
# data/book_images/image95.jpg 가 저장됨
# ('사소하지만 중요한 남극이 품은 작은 식물 이야기', '김지희 저', '지오북', '2020년 03월', '14,250', 'X')
# data/book_images/image96.jpg 가 저장됨
# ('꽃은 알고 있다', '퍼트리샤 윌트셔 저/김아림 역', '웅진지식하우스', '2019년 12월', '11,600', '8.5')
# data/book_images/image97.jpg 가 저장됨
# ('보따니스트', '마르 장송, 샤를로트 포브 저/박태신 역/정수영 감수', '도서출판가지', '2021년 11월', '14,400', 'X')
# data/book_images/image98.jpg 가 저장됨
# ('비교하며 배우는 생물학+식물분류+동물분류+화학의 기초개념 시리즈세트/전4권/우주랑사람이같다고요.동물은뼈부터다르다고요.동물이랑식물이같다고요.식물은떡잎부터다르다고요.', '노정임 글 / 안경자 그림 / 이정모 감수 외', '현암사(전집)', '2013년 02월', '44,100', 'X')
# data/book_images/image99.jpg 가 저장됨
# ('비교하며 배우는 기초 시리즈 1~4 세트 (전4권) : 생물학/식물/동물/화학', '노정임 지음,안경자 그림,이정모 감수', '현암사(전집)', '2018년 02월', '44,100', 'X')
# data/book_images/image100.jpg 가 저장됨
# ('어디에서 왔을까? 채소의 식물학', '모리구치 미쓰루 글그림 / 이진원 역 / 유영한 감수', '봄나무', '2016년 05월', '10,800', 'X')
# data/book_images/image101.jpg 가 저장됨
# ('신.약품식물학', '약품식물학분과회', '학창사', '1999년 03월', '19,000', 'X')
# data/book_images/image102.jpg 가 저장됨
# ('어린이를 위한 식물학', '지니 K. 풀브라이트 저 / 명지대학교 창조과학연구소 역', '명지대학교출판부', '2007년 02월', '18,000', 'X')
# data/book_images/image103.jpg 가 저장됨
# ('어디에서 왔을까? 과일의 비밀+곡식의 지혜+채소의 식물학 세트(전3권)-세밀화로 보는 한살이도감', '모리구치 미쓰루 글그림 / 이진원 역 / 유영한 감수', '봄나무(전집)', '2016년 03월', '32,400', 'X')
# data/book_images/image104.jpg 가 저장됨
# ('일반 식물학', '서봉보 외 공역', '월드사이언스', '2005년 03월', '30,000', 'X')
# data/book_images/image105.jpg 가 저장됨
# ('2017 EBS PEET·MEET·DEET 핵심생물학 진화 분류 식물학 생태학', '서가영 편저', '자연과과학', '2016년 04월', '18,000', '8.0')
# data/book_images/image106.jpg 가 저장됨
# ('욕망의 식물학', '마이클 폴란 저/이창신 역/최재천 감수', '서울문화사', '2002년 01월', '10,800', '7.6')
# data/book_images/image107.jpg 가 저장됨
# ('어디에서 왔을까? 세트(전5권)/과일의비밀.곡식의지혜.채소의식물학.밥상위뼈탐험.진화의비밀', '모리구치 미쓰루 글 외', '봄나무(전집)', '2016년 03월', '54,000', 'X')
# data/book_images/image108.jpg 가 저장됨
# ('Perfectica 생물학총론 6th 식물학·생태학', '강치욱 저', '에코에티카(ECOETHICA)', '2014년 02월', '11,700', 'X')
# data/book_images/image109.jpg 가 저장됨
# ('지피식물학', '방광자 저', '조경', '2009년 08월', '16,200', 'X')
# data/book_images/image110.jpg 가 저장됨
# ('최신 자생식물학', '이정식, 윤평섭 공저', '대선', '2002년 08월', '20,000', 'X')
# data/book_images/image111.jpg 가 저장됨
# ('천연약용식물학', '이호선 저', '아트하우스', '2014년 04월', '20,000', 'X')
# data/book_images/image112.jpg 가 저장됨
# ('유전자원식물학', '김성민, 신동일, 송홍선 공저', '공주대학교출판부', '2008년 08월', '22,000', 'X')
# data/book_images/image113.jpg 가 저장됨
# ('일반식물학', 'GRAHAM 저 / 강원희 등역', '월드사이언스', '2008년 02월', '30,000', 'X')
# data/book_images/image114.jpg 가 저장됨
# ('어디에서 왔을까 시리즈 1~5권 세트(문구세트+종합장 증정) : 과일의 비밀/곡식의 지혜/채소의 식물학/밥상 위 뼈 탐험/맛있는 진화의 비밀', '모리구치 미쓰루', '봄나무(전집)', '2017년 03월', '54,000', 'X')
# data/book_images/image115.jpg 가 저장됨
# ('조경식물학', '김용식 ,강호철,김광두,김동엽,김인호 편', '광일문화사', '2007년 02월', '28,000', 'X')
# data/book_images/image116.jpg 가 저장됨
# ('최신 조경식물학', '김용식저', '광일문화사', '2006년 03월', '32,000', 'X')
# data/book_images/image117.jpg 가 저장됨
# ('세밀화로 보는 어디에서 왔을까세트(전5권/곡식의 지혜+채소의 식물학+과일의 비밀+진화의 비밀+밥상 위 뼈 탐험)', '모리구치 미쓰루,이진원외', '봄나무(전집)', '2016년 04월', '54,000', 'X')
# data/book_images/image118.jpg 가 저장됨
# ('지피식물학', '방광자 저', '조경', '2005년 02월', '16,200', 'X')
# data/book_images/image119.jpg 가 저장됨
# ('강치욱 생물학총론 6 식물학·생태학', '강치욱 편저', '배움', '2018년 04월', '17,100', 'X')
# data/book_images/image120.jpg 가 저장됨
# ('메모지증정/어디에서 왔을까? 1-5권세트(전5권/과일의비밀+곡식의지혜+채소의식물학+밥상위뼈탐험+진화의비밀)', '모리구치 미쓰루 글 / 그림', '봄나무(전집)', '2017년 03월', '54,000', 'X')
# data/book_images/image121.jpg 가 저장됨
# ('어디에서 왔을까 채소의식물학+곡식의지혜+과일의비밀 묶음세트(전3권)(도감)', '모리구치 미쓰루 글그림/이진원 역/유영한 감수', '봄나무(전집)', '2017년 11월', '32,400', 'X')
# data/book_images/image122.jpg 가 저장됨
# ('환경식물학', '양운진', '동화기술', '1994년 09월', '12,000', 'X')
# data/book_images/image123.jpg 가 저장됨
# ('조경식물학', '김용식, 강호철, 김광두, 김동엽, 김민수, 김인호 공저', '광일문화사', '2013년 02월', '32,000', 'X')
# data/book_images/image124.jpg 가 저장됨
# ('약용식물학 실험', '송창길 등저', '제주대학교출판부', '1999년 08월', '8,000', 'X')
# data/book_images/image125.jpg 가 저장됨
# ('자생식물학', '이정식.윤평섭 공저', '서일', '1997년 02월', '15,000', 'X')
# data/book_images/image126.jpg 가 저장됨
# ('자원식물학', '임웅규', '서일', '1997년 02월', '15,000', 'X')
# data/book_images/image127.jpg 가 저장됨
# ('세밀화로 보는 어디에서 왔을까? 세트/전5권/진화의비밀.밥상위뼈탐험.채소의식물학.곡식의지혜.과일의비밀', '모리구치 미쓰루 글그림', '봄나무(전집)', '2016년 03월', '54,000', 'X')
# data/book_images/image128.jpg 가 저장됨
# ('약용식물학', '김원 편', '경북대학교출판부', '1997년 08월', '5,000', 'X')
# data/book_images/image129.jpg 가 저장됨
# ('식물분자생물학 연구법', '남홍길 등저', '아카데미서적', '1999년 03월', '9,000', 'X')
# data/book_images/image130.jpg 가 저장됨
# ('식물 학교에 오세요!', '김성화, 권수진 글 / 이민하 그림', '디딤돌교육(단행본)', '2006년 12월', '6,300', 'X')
# data/book_images/image131.jpg 가 저장됨
# ('Techspa 7,9급 농업직 식물작물(학)', '박혜랑,행정고시학원 편', '박문각', '2006년 01월', '18,000', 'X')
# data/book_images/image132.jpg 가 저장됨
# ('초등 동식물 학습백과 6학년', 'X', '컴퓨터찬스', '2002년 03월', '44,000', 'X')
# data/book_images/image133.jpg 가 저장됨
# ('초등 동식물 학습백과 5학년', 'X', '컴퓨터찬스', '2002년 03월', '44,000', 'X')
# data/book_images/image134.jpg 가 저장됨
# ('초등 동식물 학습백과 4학년', 'X', '컴퓨터찬스', '2002년 03월', '44,000', 'X')
# data/book_images/image135.jpg 가 저장됨
# ('초등 동식물 학습백과 3학년', 'X', '컴퓨터찬스', '2002년 03월', '44,000', 'X')
# data/book_images/image136.jpg 가 저장됨
# ('초등 동식물 학습백과 2학년', 'X', '컴퓨터찬스', '2002년 03월', '44,000', 'X')
# data/book_images/image137.jpg 가 저장됨
# ('초등 동식물 학습백과 1학년', 'X', '컴퓨터찬스', '2002년 03월', '44,000', 'X')
# data/book_images/image138.jpg 가 저장됨
# ('계몽 동식물 학습백과', 'X', '(주)계몽교육정보', 'X', '30,800', 'X')
# data/book_images/image139.jpg 가 저장됨
# ('식물 학습도감', '이지열 감수', '예림당', '1997년 08월', '18,000', '6.5')
# data/book_images/image140.jpg 가 저장됨
# ('생물학개론 3st', '강치욱 저', '에코에티카(ECOETHICA)', '2014년 12월', '27,000', 'X')
# data/book_images/image141.jpg 가 저장됨
# ('기관추천 선정필독서세트 B (전8권) - 1학년', '얀 손힐 저 / 이순미 역외', '책이랑(기획)', '2011년 04월', '67,950', 'X')
# data/book_images/image142.jpg 가 저장됨
# ('하루 한 식물', '마키노 도미타로 저 / 안은미 역 / 신현철 감수', '한빛비즈', '2016년 04월', '13,500', '9.4')
# data/book_images/image143.jpg 가 저장됨
# ('초등과학 주제학습 1~8권 묶음세트(전8권)+사은품증정(랜덤)기체 태양계로 드라이브 떠나다/호기심 달나라에 착륙하다', '성혜숙 글 / 신명환 그림', '북멘토출판사(전집)', '2017년 11월', '55,800', 'X')
# data/book_images/image144.jpg 가 저장됨
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~\anaconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File ~\anaconda3\lib\http\client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000018A5E1A2610>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# Input In [80], in <cell line: 9>()
#      61     # book_list에 추가
#      62     book_list.append(b_list)
# ---> 64 book_count=len(driver.find_elements(By.CSS_SELECTOR, '#yesSchList > li'))
#      65 j+=1
#      66 if book_count<24:
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:1284, in WebDriver.find_elements(self, by, value)
#    1280     value = '[name="%s"]' % value
#    1282 # Return empty list if driver returns null
#    1283 # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1284 return self.execute(Command.FIND_ELEMENTS, {
#    1285     'using': by,
#    1286     'value': value})['value'] or []
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     425         params['sessionId'] = self.session_id
#     427 params = self._wrap_value(params)
# --> 428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
#     430     self.error_handler.check_response(response)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:347, in RemoteConnection.execute(self, command, params)
#     345 data = utils.dump_json(params)
#     346 url = f"{self._url}{path}"
# --> 347 return self._request(command_info[0], url, body=data)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:369, in RemoteConnection._request(self, method, url, body)
#     366     body = None
#     368 if self.keep_alive:
# --> 369     response = self._conn.request(method, url, body=body, headers=headers)
#     370     statuscode = response.status
#     371 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\anaconda3\lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~\anaconda3\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     808 if not conn:
#     809     # Try again
#     810     log.warning(
#     811         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     812     )
# --> 813     return self.urlopen(
#     814         method,
#     815         url,
#     816         body,
#     817         headers,
#     818         retries,
#     819         redirect,
#     820         assert_same_host,
#     821         timeout=timeout,
#     822         pool_timeout=pool_timeout,
#     823         release_conn=release_conn,
#     824         chunked=chunked,
#     825         body_pos=body_pos,
#     826         **response_kw
#     827     )
#     829 # Handle redirect?
#     830 redirect_location = redirect and response.get_redirect_location()
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     808 if not conn:
#     809     # Try again
#     810     log.warning(
#     811         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     812     )
# --> 813     return self.urlopen(
#     814         method,
#     815         url,
#     816         body,
#     817         headers,
#     818         retries,
#     819         redirect,
#     820         assert_same_host,
#     821         timeout=timeout,
#     822         pool_timeout=pool_timeout,
#     823         release_conn=release_conn,
#     824         chunked=chunked,
#     825         body_pos=body_pos,
#     826         **response_kw
#     827     )
#     829 # Handle redirect?
#     830 redirect_location = redirect and response.get_redirect_location()
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     808 if not conn:
#     809     # Try again
#     810     log.warning(
#     811         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     812     )
# --> 813     return self.urlopen(
#     814         method,
#     815         url,
#     816         body,
#     817         headers,
#     818         retries,
#     819         redirect,
#     820         assert_same_host,
#     821         timeout=timeout,
#     822         pool_timeout=pool_timeout,
#     823         release_conn=release_conn,
#     824         chunked=chunked,
#     825         body_pos=body_pos,
#     826         **response_kw
#     827     )
#     829 # Handle redirect?
#     830 redirect_location = redirect and response.get_redirect_location()
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782 elif isinstance(e, (SocketError, HTTPException)):
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#     790 # Keep track of the error for the retry warning.
#
# File ~\anaconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     581 new_retry = self.new(
#     582     total=total,
#     583     connect=connect,
#    (...)
#     588     history=history,
#     589 )
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     596 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=8518): Max retries exceeded with url: /session/156dc2c61ef0ada7d5bb3840c9cdb2b9/elements (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000018A5E1A2610>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))

# %%
# DataFrame 작성
df=pd.DataFrame(book_list,columns=['title','author','publisher','date','price','rating'])
# df.to_csv('data/books.csv', index=False)
df
# Out:
#                                                  title  \
# 0                                             식물학자의 노트
# 1                                          가드닝을 위한 식물학
# 2                                       이일하 교수의 식물학 산책
# 3                                   재밌어서 밤새 읽는 식물학 이야기
# 4                                      식물학자의 노트 (큰글자책)
# ..                                                 ...
# 139                                            식물 학습도감
# 140                                          생물학개론 3st
# 141                         기관추천 선정필독서세트 B (전8권) - 1학년
# 142                                            하루 한 식물
# 143  초등과학 주제학습 1~8권 묶음세트(전8권)+사은품증정(랜덤)기체 태양계로 드라이브...
#
#                           author         publisher       date   price rating
# 0                        신혜우 글그림               김영사  2021년 04월  17,820    9.8
# 1                제프 호지 저 / 김정은 역                따비  2021년 11월  19,800      X
# 2                          이일하 저              궁리출판  2022년 05월  19,800      X
# 3       이나가키 히데히로 저/박현아 역/류충민 감수                더숲  2019년 08월  10,800    9.3
# 4                        신혜우 글그림               김영사  2021년 09월  22,000   10.0
# ..                           ...               ...        ...     ...    ...
# 139                       이지열 감수               예림당  1997년 08월  18,000    6.5
# 140                        강치욱 저  에코에티카(ECOETHICA)  2014년 12월  27,000      X
# 141              얀 손힐 저 / 이순미 역외           책이랑(기획)  2011년 04월  67,950      X
# 142  마키노 도미타로 저 / 안은미 역 / 신현철 감수              한빛비즈  2016년 04월  13,500    9.4
# 143               성혜숙 글 / 신명환 그림        북멘토출판사(전집)  2017년 11월  55,800      X
#
# [144 rows x 6 columns]

# %%
# mysql에 데이터 저장
conn=pymysql.connect(host='localhost',user='lyk',password='1234',db='pydb',charset='utf8')
cursor=conn.cursor()
sql="insert into yes_book_practice(title,author,publisher,date,price,rating) values(%s,%s,%s,%s,%s,%s)"
cursor.executemany(sql,book_list)
conn.commit()
conn.close()
