# %%
import csv 
import sys
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv("data/2008.csv",sep=",") # csv는 기본적으로 ,로 구분됨
df1[:10]
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   1343.0        1325   1451.0
# 1  2008      1           3          4   1125.0        1120   1247.0
# 2  2008      1           3          4   2009.0        2015   2136.0
# 3  2008      1           3          4    903.0         855   1203.0
# 4  2008      1           3          4   1423.0        1400   1726.0
# 5  2008      1           3          4   2024.0        2020   2325.0
# 6  2008      1           3          4   1753.0        1745   2053.0
# 7  2008      1           3          4    622.0         620    935.0
# 8  2008      1           3          4   1944.0        1945   2210.0
# 9  2008      1           3          4   1453.0        1425   1716.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1435            WN        588  ...    4.0      9.0          0
# 1        1245            WN       1343  ...    3.0      8.0          0
# ...

# %%
print(df1.shape)
print(df1.columns)
# Out:
# (2389217, 29)
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df2=df1[['Year','Month','ArrDelay','DepDelay']]
df2.tail()
result=df2.groupby(['Month']).mean()
result
# Out:
#          Year   ArrDelay   DepDelay
# Month
# 1      2008.0  10.188856  11.476096
# 2      2008.0  13.077837  13.706226
# 3      2008.0  11.192365  12.491269
# 4      2008.0   6.807297   8.201133
