# %%
import pandas as pd

# %%
city = pd.read_csv('data/incheon_city.csv')

# print (city[city['dong']=='연수2동'])
dong_list = list(city.iloc[97:,:]['dong'])
dong_list
# dong_list
# city[city['dong']=='일신동']
# Out:
# ['일신동',
#  '십정1동',
#  '십정2동',
#  '효성1동',
#  '효성2동',
#  '계산1동',
#  '계산2동',
#  '계산3동',
#  '계산4동',
#  '작전1동',
#  '작전2동',
#  '작전서운동',
#  '계양1동',
#  '계양2동',
#  '계양3동',
#  '검암경서동',
#  '연희동',
#  '청라1동',
#  '청라2동',
#  '청라3동',
#  '가정1동',
#  '가정2동',
#  '가정3동',
#  '석남1동',
#  '석남2동',
#  '석남3동',
#  '신현원창동',
#  '가좌1동',
#  '가좌2동',
#  '가좌3동',
#  '가좌4동',
#  '검단동',
#  '불로대곡동',
#  '원당동',
#  '당하동',
#  '오류왕길동',
#  '마전동',
#  '아라동',
#  '강화읍',
#  '선원면',
#  '불은면',
#  '길상면',
#  '화도면',
#  '양도면',
#  '내가면',
#  '하점면',
#  '양사면',
#  '송해면',
#  '교동면',
#  '삼산면',
#  '서도면',
#  '북도면',
#  '백령면',
#  '대청면',
#  '덕적면',
#  '영흥면',
#  '자월면',
#  '연평면']

# %%
city_code = list(city.iloc[47:47+50,:]['id'])
city_code
# Out:
# [2818576200,
#  2818576300,
#  2818576600,
#  2818578000,
#  2818579000,
#  2818579500,
#  2818582000,
#  2818583000,
#  2818584000,
#  2818585000,
#  2818586000,
#  2820051000,
#  2820052000,
#  2820052100,
#  2820052200,
#  2820053000,
#  2820054000,
#  2820055000,
#  2820055100,
#  2820056000,
#  2820057000,
#  2820058000,
#  2820058100,
#  2820058200,
#  2820058300,
#  2820065000,
#  2820065500,
#  2820066000,
#  2820069000,
#  2820070000,
#  2820071000,
#  2823751000,
#  2823752000,
#  2823753000,
#  2823754000,
#  2823755000,
#  2823756000,
#  2823757000,
#  2823758000,
#  2823758100,
#  2823758200,
#  2823759100,
#  2823759200,
#  2823764100,
#  2823764200,
#  2823764600,
#  2823764800,
#  2823765000,
#  2823766000,
#  2823766100]

# %%
import pandas as pd

for idx, dong in enumerate(dong_list):
    dong_pd = pd.read_csv(r'data\wheather_hour\%s_강수_202101_202112.csv'%(dong))
    humidity= pd.read_csv(r'data\wheather_hour\%s_습도_202101_202112.csv'%(dong)).iloc[:,-1]
    temperature= pd.read_csv(r'data\wheather_hour\%s_기온_202101_202112.csv'%(dong)).iloc[:,-1]
    wind_speed = pd.read_csv(r'data\wheather_hour\%s_풍속_202101_202112.csv'%(dong)).iloc[:,-1]

    dong_pd.columns=['day','hour','precipitation']

    # dong_pd['city_id']=city_code[idx]
    dong_pd['humidity']=humidity
    dong_pd['wind_speed']=wind_speed
    dong_pd['temperature']=temperature
    dong_pd['dong']=dong
    # day 공백 제거
    dong_pd['day'] = dong_pd['day'].apply(lambda x : x.strip())
    # 필요없는 문자열 제거
    dong_pd =pd.DataFrame([ x for i,x in dong_pd.iterrows() if len(x['day'])<3 ])
    
    month=0
    date_list=[]
    for i, val in dong_pd.iterrows():
        if val['day']=='1' and val['hour']==0.0:
            month+=1
        date='2021.%s.%s'%(month,val['day'])
        date_list.append(date)

    dong_pd['date']=date_list
    del dong_pd['day']

    dong_pd.to_csv('data/wheather_hour/%s_시간별날씨_202101_202112.csv'%dong, index=False)
    print('%s ::: save %s wheather data'%(idx, dong))
# Out:
# 0 ::: save 연수2동 wheather data
# 1 ::: save 연수3동 wheather data
# 2 ::: save 청학동 wheather data
# 3 ::: save 동춘1동 wheather data
# 4 ::: save 동춘2동 wheather data
# 5 ::: save 동춘3동 wheather data
# 6 ::: save 송도1동 wheather data
# 7 ::: save 송도2동 wheather data
# 8 ::: save 송도3동 wheather data
# 9 ::: save 송도4동 wheather data
# 10 ::: save 송도5동 wheather data
# 11 ::: save 구월1동 wheather data
# 12 ::: save 구월2동 wheather data
# 13 ::: save 구월3동 wheather data
# 14 ::: save 구월4동 wheather data
# 15 ::: save 간석1동 wheather data
# 16 ::: save 간석2동 wheather data
# 17 ::: save 간석3동 wheather data
# 18 ::: save 간석4동 wheather data
# 19 ::: save 만수1동 wheather data
# 20 ::: save 만수2동 wheather data
# 21 ::: save 만수3동 wheather data
# 22 ::: save 만수4동 wheather data
# 23 ::: save 만수5동 wheather data
# 24 ::: save 만수6동 wheather data
# 25 ::: save 장수서창동 wheather data
# 26 ::: save 서창2동 wheather data
# 27 ::: save 남촌도림동 wheather data
# 28 ::: save 논현1동 wheather data
# 29 ::: save 논현2동 wheather data
# 30 ::: save 논현고잔동 wheather data
# 31 ::: save 부평1동 wheather data
# 32 ::: save 부평2동 wheather data
# 33 ::: save 부평3동 wheather data
# 34 ::: save 부평4동 wheather data
# 35 ::: save 부평5동 wheather data
# 36 ::: save 부평6동 wheather data
# 37 ::: save 산곡1동 wheather data
# 38 ::: save 산곡2동 wheather data
# 39 ::: save 산곡3동 wheather data
# 40 ::: save 산곡4동 wheather data
# 41 ::: save 청천1동 wheather data
# 42 ::: save 청천2동 wheather data
# 43 ::: save 갈산1동 wheather data
# 44 ::: save 갈산2동 wheather data
# 45 ::: save 삼산1동 wheather data
# 46 ::: save 삼산2동 wheather data
# 47 ::: save 부개1동 wheather data
# 48 ::: save 부개2동 wheather data
# 49 ::: save 부개3동 wheather data

# %%
month=0
date_list=[]
for idx, dong in dong_pd.iterrows():
    if dong['day']=='1' and dong['hour']==0.0:
        month+=1
    date='2021.%s.%s'%(month,dong['day'])
    date_list.append(date)

dong_pd['date']=date_list
del dong_pd['day']
dong_pd
# Out:
#         hour  precipitation     city_id  humidity  wind_speed  temperature  \
# 0        0.0            0.0  2823766100      54.0         1.2         -3.4
# 1      100.0            0.0  2823766100      52.0         2.2         -2.3
# 2      200.0            0.0  2823766100      56.0         2.2         -1.3
# 3      300.0            0.0  2823766100      56.0         2.3         -0.2
# 4      400.0            0.0  2823766100      58.0         2.2          0.5
# ...      ...            ...         ...       ...         ...          ...
# 8766  1900.0            0.0  2823766100      70.0         0.0        -11.3
# 8767  2000.0            0.0  2823766100      74.0         0.0        -11.8
# 8768  2100.0            0.0  2823766100      75.0         0.0        -11.7
# 8769  2200.0            0.0  2823766100      75.0         0.0        -11.1
# 8770  2300.0            0.0  2823766100      58.0         0.0         -7.4
#
#             date
# 0       2021.1.1
# 1       2021.1.1
# 2       2021.1.1
# 3       2021.1.1
# 4       2021.1.1
# ...          ...
# 8766  2021.12.31
# 8767  2021.12.31
# 8768  2021.12.31
# 8769  2021.12.31
# 8770  2021.12.31
#
# [8760 rows x 7 columns]

# %%
#for idx, dong in enumerate(dong_list):
dong_pd = pd.read_csv('data/wheather_hour/연수1동_시간별날씨_202101_202112.csv')

print(dong_pd[dong_pd['wind_speed']==-1],'\n===============================================================================')

idxs = dong_pd[dong_pd['wind_speed']==-1].index
for i in idxs:
    print(i)
    print(dong_pd.iloc[[i-1,i+1]])
    avg = dong_pd.iloc[[i-1,i+1],3].mean()
    dong_pd.iloc[i,3]=avg

    print('mean 1ago 1after ::',dong_pd.iloc[i,4],'\n')
dong_pd = dong_pd.drop(dong_pd[dong_pd['humidity']==-1].index)
# Out:
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 1983  1500.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 3279  1500.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 3282  1800.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 3329  1700.0            0.0      85.0        -1.0    15.900000  연수1동
# 3341   500.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 3589  1300.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 3615  1500.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 3616  1600.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 3677   500.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 4062   600.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 4376   800.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 4614   600.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 5301  2100.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 5308   400.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 6006   600.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 6416   800.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 6632   800.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 6719  2300.0            0.0      84.0        -1.0    19.700001  연수1동
# 7028  2000.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 7664   800.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 7794  1800.0           -1.0      -1.0        -1.0   -50.000000  연수1동
# 7878   600.0           -1.0      -1.0        -1.0   -50.000000  연수1동
#
#             date
# 1983   2021.3.24
# 3279   2021.5.17
# 3282   2021.5.17
# 3329   2021.5.19
# 3341   2021.5.20
# 3589   2021.5.30
# 3615   2021.5.31
# 3616   2021.5.31
# 3677    2021.6.3
# 4062   2021.6.19
# 4376    2021.7.2
# 4614   2021.7.12
# 5301    2021.8.9
# 5308   2021.8.10
# 6006    2021.9.8
# 6416   2021.9.25
# 6632   2021.10.4
# 6719   2021.10.7
# 7028  2021.10.20
# 7664  2021.11.16
# 7794  2021.11.21
# 7878  2021.11.25
# ===============================================================================
# 1983
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 1982  1400.0            0.0      86.0         0.9          9.5  연수1동
# 1984  1600.0            0.0      87.0         0.5          7.1  연수1동
#
#            date
# 1982  2021.3.24
# 1984  2021.3.24
# mean 1ago 1after :: -50.0
#
# 3279
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 3278  1400.0            0.0     100.0         0.2         13.1  연수1동
# 3280  1600.0            0.0     100.0         0.1         13.5  연수1동
#
#            date
# 3278  2021.5.17
# 3280  2021.5.17
# mean 1ago 1after :: -50.0
#
# 3282
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 3281  1700.0            0.0     100.0         0.5         13.2  연수1동
# 3283  1900.0            0.0     100.0         0.7         13.2  연수1동
#
#            date
# 3281  2021.5.17
# 3283  2021.5.17
# mean 1ago 1after :: -50.0
#
# 3329
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 3328  1600.0            0.0      84.0         0.1         15.9  연수1동
# 3330  1800.0            0.0      85.0         0.6         17.1  연수1동
#
#            date
# 3328  2021.5.19
# 3330  2021.5.19
# mean 1ago 1after :: 15.9
#
# 3341
#        hour  precipitation  humidity  wind_speed  temperature  dong       date
# 3340  400.0            0.0      40.0         3.5    23.100000  연수1동  2021.5.20
# 3342  600.0            0.0      49.0         3.5    20.799999  연수1동  2021.5.20
# mean 1ago 1after :: -50.0
#
# 3589
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 3588  1200.0            4.5      90.0         1.3         17.0  연수1동
# 3590  1400.0            0.5      89.0         1.2         16.6  연수1동
#
#            date
# 3588  2021.5.30
# 3590  2021.5.30
# mean 1ago 1after :: -50.0
#
# 3615
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 3614  1400.0            0.0      80.0         1.3    17.299999  연수1동
# 3616  1600.0           -1.0      -1.0        -1.0   -50.000000  연수1동
#
#            date
# 3614  2021.5.31
# 3616  2021.5.31
# mean 1ago 1after :: -50.0
#
# 3616
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 3615  1500.0           -1.0      -1.0        0.15        -50.0  연수1동
# 3617  1700.0            0.0      71.0        1.00         18.1  연수1동
#
#            date
# 3615  2021.5.31
# 3617  2021.5.31
# mean 1ago 1after :: -50.0
#
# 3677
#        hour  precipitation  humidity  wind_speed  temperature  dong      date
# 3676  400.0            2.0      90.0         1.2         18.4  연수1동  2021.6.3
# 3678  600.0            2.5      92.0         1.6         18.0  연수1동  2021.6.3
# mean 1ago 1after :: -50.0
#
# 4062
#        hour  precipitation  humidity  wind_speed  temperature  dong       date
# 4061  500.0            0.0      60.0         2.1         24.5  연수1동  2021.6.19
# 4063  700.0            0.0      62.0         1.7         24.1  연수1동  2021.6.19
# mean 1ago 1after :: -50.0
#
# 4376
#        hour  precipitation  humidity  wind_speed  temperature  dong      date
# 4375  700.0            0.0      47.0         2.0    32.000000  연수1동  2021.7.2
# 4377  900.0            0.0      51.0         1.5    30.299999  연수1동  2021.7.2
# mean 1ago 1after :: -50.0
#
# 4614
#        hour  precipitation  humidity  wind_speed  temperature  dong       date
# 4613  500.0            0.0      58.0         1.8         31.6  연수1동  2021.7.12
# 4615  700.0            0.0      59.0         1.0         31.9  연수1동  2021.7.12
# mean 1ago 1after :: -50.0
#
# 5301
#         hour  precipitation  humidity  wind_speed  temperature  dong      date
# 5300  2000.0            0.0      88.0         1.1    24.200001  연수1동  2021.8.9
# 5302  2200.0            0.0      70.0         1.6    27.000000  연수1동  2021.8.9
# mean 1ago 1after :: -50.0
#
# 5308
#        hour  precipitation  humidity  wind_speed  temperature  dong       date
# 5307  300.0            0.0      60.0         2.9    30.200001  연수1동  2021.8.10
# 5309  500.0            0.0      62.0         2.8    30.200001  연수1동  2021.8.10
# mean 1ago 1after :: -50.0
#
# 6006
#        hour  precipitation  humidity  wind_speed  temperature  dong      date
# 6005  500.0            0.0      63.0         2.9    25.900000  연수1동  2021.9.8
# 6007  700.0            0.0      63.0         2.6    24.799999  연수1동  2021.9.8
# mean 1ago 1after :: -50.0
#
# 6416
#        hour  precipitation  humidity  wind_speed  temperature  dong       date
# 6415  700.0            0.0      61.0         1.5    23.700001  연수1동  2021.9.25
# 6417  900.0            0.0      78.0         0.7    21.200001  연수1동  2021.9.25
# mean 1ago 1after :: -50.0
#
# 6632
#        hour  precipitation  humidity  wind_speed  temperature  dong       date
# 6631  700.0            0.0      83.0         2.3         24.9  연수1동  2021.10.4
# 6633  900.0            0.0      80.0         3.8         25.0  연수1동  2021.10.4
# mean 1ago 1after :: -50.0
#
# 6719
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 6718  2200.0            0.0      85.0         1.3    19.299999  연수1동
# 6720     0.0            0.0      86.0         1.4    19.900000  연수1동
#
#            date
# 6718  2021.10.7
# 6720  2021.10.8
# mean 1ago 1after :: 19.700001
#
# 7028
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 7027  1900.0            0.0      93.0         0.1          4.8  연수1동
# 7029  2100.0            0.0      93.0         0.8          4.6  연수1동
#
#             date
# 7027  2021.10.20
# 7029  2021.10.20
# mean 1ago 1after :: -50.0
#
# 7664
#        hour  precipitation  humidity  wind_speed  temperature  dong  \
# 7663  700.0            0.0      53.0         2.1         11.3  연수1동
# 7665  900.0            0.0      61.0         1.6         10.2  연수1동
#
#             date
# 7663  2021.11.16
# 7665  2021.11.16
# mean 1ago 1after :: -50.0
#
# 7794
#         hour  precipitation  humidity  wind_speed  temperature  dong  \
# 7793  1700.0            0.0      58.0         3.6          7.7  연수1동
# 7795  1900.0            0.0      51.0         4.5          5.9  연수1동
#
#             date
# 7793  2021.11.21
# 7795  2021.11.21
# mean 1ago 1after :: -50.0
#
# 7878
#        hour  precipitation  humidity  wind_speed  temperature  dong  \
# 7877  500.0            0.0      37.0         2.9          9.7  연수1동
# 7879  700.0            0.0      41.0         3.6          8.1  연수1동
#
#             date
# 7877  2021.11.25
# 7879  2021.11.25
# mean 1ago 1after :: -50.0

# %%
dong_pd['humidity']['dong

# %%
dong_pd['precipitation'].unique()
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  3.5,  2.5,  3. ,  4.5,  5. ,  7. ,
#         4. , -1. ,  5.5,  7.5,  9. ,  6.5,  8.5,  6. ,  8. , 22.5, 20.5,
#        12. ,  9.5, 14. , 18. , 17.5, 10.5, 15.5, 16. ])
