# %%
import numpy as np
import pandas as pd

# %%
pot_pd=pd.read_csv('data/인천포트홀발생.csv', encoding='utf-8')
pot_pd
# Out:
#       Unnamed: 0  hazard_type  region_humid  link_longitude  link_degree  \
# 0              0            0          76.0      126.685022   226.353670
# 1              1            0          76.0      126.696083   226.072053
# 2              2            0          87.0      126.689165    36.709465
# 3              3            0          59.0      126.734518    66.650647
# 4              4            0          59.0      126.696295   226.072053
# ...          ...          ...           ...             ...          ...
# 1401        1401            0          62.0      126.648390   336.239509
# 1402        1402            0          55.0      126.696865   208.919899
# 1403        1403            0          45.0      126.710640   198.516046
# 1404        1404            0          45.0      126.707800   345.056452
# 1405        1405            0          54.0      126.648664    67.090115
#
#       region_wind_speed  hazard_image_width fnode_name   latitude      f_node  \
# 0                  3.60                1920      경원고가교  37.409824  1640004000
# 1                  3.60                1920     선학지하차도  37.420063  1640009700
# 2                  2.06                1920   번영로제3사거리  37.403645  1650006700
# 3                  5.86                1920      샤인유치원  37.409744  1650026800
# 4                  3.09                1920     선학지하차도  37.420310  1640009700
# ...                 ...                 ...        ...        ...         ...
# 1401               3.09                1920      용현사거리  37.459873  1630009300
# 1402               3.09                1920     선학역사거리  37.421093  1640012400
# 1403               2.06                1920      부평사거리  37.478928  1660003100
# 1404               2.06                1920      부안고가교  37.486385  1660004400
# 1405               5.66                1920   미추홀구-연수구  37.436370  1640094900
#
#       ...                                       hazard_image        full_addr  \
# 0     ...  https://motov-label-studio-production.s3.ap-no...   인천광역시 연수구 연수2동
# 1     ...  https://motov-label-studio-production.s3.ap-no...   인천광역시 연수구 연수3동
# 2     ...  https://motov-label-studio-production.s3.ap-no...  인천광역시 남동구 논현고잔동
# 3     ...  https://motov-label-studio-production.s3.ap-no...   인천광역시 남동구 논현1동
# 4     ...  https://motov-label-studio-production.s3.ap-no...   인천광역시 연수구 연수3동
# ...   ...                                                ...              ...
# 1401  ...  https://motov-label-studio-production.s3.ap-no...  인천광역시 미추홀구 숭의2동
# 1402  ...  https://motov-label-studio-production.s3.ap-no...   인천광역시 연수구 연수3동
# 1403  ...  https://motov-label-studio-production.s3.ap-no...   인천광역시 부평구 부평3동
# 1404  ...  https://motov-label-studio-production.s3.ap-no...   인천광역시 부평구 부평3동
# 1405  ...  https://motov-label-studio-production.s3.ap-no...  인천광역시 미추홀구 학익1동
#
#       region_wind_dir  car_direction  car_speed  \
# 0               340.0     257.849518  13.324111
# 1               340.0     244.825661  23.150000
# 2               340.0       9.812028   6.070445
# 3               320.0      75.812439   8.076777
# 4               260.0     251.040848   8.334000
# ...               ...            ...        ...
# 1401            290.0      65.159027   9.877334
# 1402            290.0     237.470970  10.854777
# 1403            270.0      79.563202   7.768111
# 1404            270.0      73.848877  11.523556
# 1405            300.0     258.874092   7.613778
#
#                                                   label    district  \
# 0     {'IMU': None, 'road_hazard': [{'rotation': 0, ...  2818576200
# 1     {'IMU': None, 'road_hazard': [{'rotation': 0, ...  2818576300
# 2     {'IMU': None, 'road_hazard': [{'rotation': 0, ...  2820071000
# 3     {'IMU': None, 'road_hazard': [{'rotation': 0, ...  2820069000
# 4     {'IMU': None, 'road_hazard': [{'rotation': 0, ...  2818576300
# ...                                                 ...         ...
# 1401  {'IMU': None, 'road_hazard': [{'rotation': 0, ...  2817751000
# 1402  {'IMU': None, 'road_hazard': [{'rotation': 0, ...  2818576300
# 1403  {'IMU': None, 'road_hazard': [{'rotation': 0, ...  2823753000
# 1404  {'IMU': None, 'road_hazard': [{'rotation': 0, ...  2823753000
# 1405  {'IMU': None, 'road_hazard': [{'rotation': 0, ...  2817758000
#
#       hazard_state link_latitude  tnode_name
# 0                0     37.409757       연수사거리
# 1                0     37.419969     신연수역사거리
# 2                0     37.403638    번영로제2사거리
# 3                0     37.409824    북한왕찹쌀순대집
# 4                0     37.420223     신연수역사거리
# ...            ...           ...         ...
# 1401             0     37.459878       숭의오거리
# 1402             0     37.421082       인보유치원
# 1403             0     37.478889       부평삼거리
# 1404             0     37.486390       신촌사거리
# 1405             0     37.436572        학익JC
#
# [1406 rows x 41 columns]

# %%
del pot_pd['hazard_type']
del pot_pd['region_humid']
del pot_pd['link_degree']
del pot_pd['region_wind_speed']
del pot_pd['hazard_image_width']
del pot_pd['f_node']
del pot_pd['road_rank']
del pot_pd['created_at']
del pot_pd['car_vibrate_y']
del pot_pd['t_node']
del pot_pd['car_vibrate_z']
del pot_pd['car_vibrate_x']
del pot_pd['region_temp']
del pot_pd['IMU_data']
del pot_pd['link_length']
del pot_pd['dist_level3']
del pot_pd['car_temp']
del pot_pd['road_type']
del pot_pd['hazard_grade']
del pot_pd['dist_level2']
del pot_pd['hazard_count']
del pot_pd['id']
del pot_pd['hazard_image_height']
del pot_pd['road_name']
del pot_pd['hazard_image']
del pot_pd['full_addr']
del pot_pd['car_direction']
del pot_pd['car_speed']
del pot_pd['label']
del pot_pd['district']
del pot_pd['hazard_state']
del pot_pd['tnode_name']

# %%
pot_pd=pot_pd.drop(pot_pd.columns[0], axis=1)

# %%
pot_pd
# Out:
#        latitude     link_id   longitude
# 0     37.409824  1640014400  126.684960
# 1     37.420063  1640025800  126.695970
# 2     37.403645  1650028700  126.689156
# 3     37.409744  1650080300  126.734550
# 4     37.420310  1640025800  126.696190
# ...         ...         ...         ...
# 1401  37.459873  1630033400  126.648380
# 1402  37.421093  1640035900  126.696850
# 1403  37.478928  1650010901  126.710495
# 1404  37.486385  1660012900  126.707780
# 1405  37.436370  1630166900  126.648720
#
# [1406 rows x 3 columns]

# %%
pot_1=pot_pd[:200]
pot_1.to_csv('data/pot/pot_pd1.csv', encoding='CP949', index=False)

# %%
pot_2=pot_pd[201:400]
pot_3=pot_pd[401:600]
pot_4=pot_pd[601:800]
pot_5=pot_pd[801:1000]
pot_6=pot_pd[1001:1200]
pot_7=pot_pd[1201:1400]
pot_8=pot_pd[1401:]
pot_2.to_csv('data/pot/pot_pd2.csv', encoding='CP949', index=False)
pot_3.to_csv('data/pot/pot_pd3.csv', encoding='CP949', index=False)
pot_4.to_csv('data/pot/pot_pd4.csv', encoding='CP949', index=False)
pot_5.to_csv('data/pot/pot_pd5.csv', encoding='CP949', index=False)
pot_6.to_csv('data/pot/pot_pd6.csv', encoding='CP949', index=False)
pot_7.to_csv('data/pot/pot_pd7.csv', encoding='CP949', index=False)
pot_8.to_csv('data/pot/pot_pd8.csv', encoding='CP949', index=False)

# %%
pt1=pd.read_csv('data/pot/potshp/pot_pd1.shp.csv', encoding='CP949')
pt1
# Out:
#       No   latitude     link_id   longitude  경도                 지번주소  \
# 0      1  37.409824  1640014400  126.684960 NaN    인천광역시 연수구 연수동 647
# 1      2  37.420063  1640025800  126.695970 NaN    인천광역시 연수구 연수동 637
# 2      3  37.403645  1650028700  126.689156 NaN    인천광역시 남동구 고잔동 778
# 3      4  37.409744  1650080300  126.734550 NaN    인천광역시 남동구 논현동 685
# 4      5  37.420310  1640025800  126.696190 NaN    인천광역시 연수구 연수동 637
# ..   ...        ...         ...         ...  ..                  ...
# 194  196  37.409943  1640015700  126.685550 NaN    인천광역시 연수구 연수동 647
# 195  197  37.408405  1650032102  126.687420 NaN    인천광역시 남동구 고잔동 747
# 196  198  37.421550  1640035900  126.697174 NaN    인천광역시 연수구 연수동 637
# 197  199  37.422314  1640035301  126.647170 NaN  인천광역시 연수구 옥련동 473-1
# 198  200  37.418564  1640025600  126.692930 NaN    인천광역시 연수구 연수동 646
#
#                       도로명주소
# 0        인천광역시 연수구 청능대로 175
# 1           인천광역시 연수구 선학로 2
# 2     인천광역시 남동구 남동서로144번길 3
# 3    인천광역시 남동구 청능대로715번길 63
# 4           인천광역시 연수구 선학로 2
# ..                      ...
# 194      인천광역시 연수구 청능대로 205
# 195      인천광역시 남동구 승기천로 174
# 196      인천광역시 연수구 경원대로 412
# 197       인천광역시 연수구 한나루로 84
# 198      인천광역시 연수구 원인재로 286
#
# [199 rows x 7 columns]
