# %%
import pandas as pd

# %%
city = pd.read_csv('data/incheon_city.csv')
# print (city[city['dong']=='연수2동'])
dong_list = list(city['dong'])

len(dong_list)
# Out:
# 155

# %%
borders = pd.read_csv('data/update_city_map.csv')

# %%
for idx, dong in enumerate(dong_list):
    dong_pd = pd.read_csv('data/wheather_hour/%s_시간별날씨_202101_202112.csv'%dong)
    # print(dong_pd[dong_pd['wind_speed']==-1],'\n===============================================================================')

    # dong_pd['precipitation'].value_counts()
    # dong_pd['humidity'].unique()
    # dong_pd['wind_speed'].unique()
    # dong_pd['temperature'].unique()
    
    # dong_pd[dong_pd['humidity']==-1]
    
    idxs = dong_pd[dong_pd['wind_speed']==-1].index
    
    for i in idxs:
        # print(dong_pd.iloc[[i-1,i+1]])
        d1 = dong_pd.iloc[[i-1],3]
        d2 = dong_pd.iloc[[i+1],3]
        
        if dong_pd.iloc[[i-1],3].any()<0:
            d1 = dong_pd.iloc[[i-2],3]
        if dong_pd.iloc[[i+1],3].any()<0:
            d2 = dong_pd.iloc[[i+2],3]
            
        avg = (list(d1)[0]+list(d2)[0])/2
        dong_pd.iloc[i,3]=avg

        # print('mean 1ago 1after ::',dong_pd.iloc[i],'\n')
    
    dong_pd = dong_pd.drop(dong_pd[dong_pd['humidity']==-1].index)
    
    
    dong_pd['date'] = pd.to_datetime(dong_pd['date'])
    
    temp_max=dong_pd.groupby(['date'])[['temperature']].max()
    temp_min=dong_pd.groupby(['date'])[['temperature']].min()
    temp_avg=dong_pd.groupby(['date'])[['temperature']].mean()
    
    hum_avg=dong_pd.groupby(['date'])[['humidity']].mean()
    hum_min=dong_pd.groupby(['date'])[['humidity']].min()
    
    aqua_sum=dong_pd.groupby(['date'])['precipitation'].sum()
    
    dong_pd = pd.merge(temp_max,temp_min, left_index=True, right_index=True, how='inner')
    dong_pd = pd.merge(dong_pd,temp_avg, left_index=True, right_index=True, how='inner')
    dong_pd = pd.merge(dong_pd,hum_avg, left_index=True, right_index=True, how='inner')
    dong_pd = pd.merge(dong_pd,hum_min, left_index=True, right_index=True, how='inner')
    dong_pd = pd.merge(dong_pd,aqua_sum, left_index=True, right_index=True, how='inner')
    
    dong_pd=dong_pd.reset_index()
    dong_pd.columns=['date','temp_max','temp_min','temp_avg','hum_avg','hum_min','aqua_sum']
    
    dong_pd['region_id'] = list(borders[borders['ADM_DR_NM']==dong]['ADM_DR_CD'])[0]
    # dong_pd['region']=dong
    print(dong_pd)
    dong_pd.to_csv('data/weather_day/%s_일일_날씨_202101_202112.csv'%dong,index=False,float_format='%.2f')
    print('%s_3일_날씨_202101_202112.csv 저장 완료!'%dong)
# Out:
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2301052
# 1      2301052
# 2      2301052
# 3      2301052
# 4      2301052
# ..         ...
# 360    2301052
# 361    2301052
# 362    2301052
# 363    2301052
# 364    2301052
#
# [365 rows x 8 columns]
# 연안동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2301053
# 1      2301053
# 2      2301053
# 3      2301053
# 4      2301053
# ..         ...
# 360    2301053
# 361    2301053
# 362    2301053
# 363    2301053
# 364    2301053
#
# [365 rows x 8 columns]
# 신포동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2301054
# 1      2301054
# 2      2301054
# 3      2301054
# 4      2301054
# ..         ...
# 360    2301054
# 361    2301054
# 362    2301054
# 363    2301054
# 364    2301054
#
# [365 rows x 8 columns]
# 신흥동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2207068
# 1      2207068
# 2      2207068
# 3      2207068
# 4      2207068
# ..         ...
# 360    2207068
# 361    2207068
# 362    2207068
# 363    2207068
# 364    2207068
#
# [365 rows x 8 columns]
# 도원동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2301057
# 1      2301057
# 2      2301057
# 3      2301057
# 4      2301057
# ..         ...
# 360    2301057
# 361    2301057
# 362    2301057
# 363    2301057
# 364    2301057
#
# [365 rows x 8 columns]
# 율목동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2301058
# 1      2301058
# 2      2301058
# 3      2301058
# 4      2301058
# ..         ...
# 360    2301058
# 361    2301058
# 362    2301058
# 363    2301058
# 364    2301058
#
# [365 rows x 8 columns]
# 동인천동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2301060
# 1      2301060
# 2      2301060
# 3      2301060
# 4      2301060
# ..         ...
# 360    2301060
# 361    2301060
# 362    2301060
# 363    2301060
# 364    2301060
#
# [365 rows x 8 columns]
# 개항동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.3      -8.5 -3.462500  60.291667     42.0       0.0
# 1   2021-01-02      -0.6      -9.4 -5.062500  50.750000     38.0       0.0
# 2   2021-01-03      -0.9      -8.3 -5.170833  50.708333     32.0       0.0
# 3   2021-01-04       0.1      -6.7 -2.279167  62.500000     41.0       0.0
# 4   2021-01-05      -2.5     -12.4 -7.716667  54.291667     35.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.4      -9.0 -5.937500  83.208333     52.0       0.0
# 361 2021-12-28       1.7      -3.1 -0.412500  75.375000     48.0       0.0
# 362 2021-12-29       7.5      -6.8 -0.066667  60.916667     50.0       0.0
# 363 2021-12-30       0.0      -7.9 -4.029167  45.333333     32.0       0.0
# 364 2021-12-31      -2.7      -9.7 -6.575000  42.916667     28.0       0.0
#
#      region_id
# 0      2301065
# 1      2301065
# 2      2301065
# 3      2301065
# 4      2301065
# ..         ...
# 360    2301065
# 361    2301065
# 362    2301065
# 363    2301065
# 364    2301065
#
# [365 rows x 8 columns]
# 영종동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.3      -8.5 -3.462500  60.291667     42.0       0.0
# 1   2021-01-02      -0.6      -9.4 -5.062500  50.750000     38.0       0.0
# 2   2021-01-03      -0.9      -8.3 -5.170833  50.708333     32.0       0.0
# 3   2021-01-04       0.1      -6.7 -2.279167  62.500000     41.0       0.0
# 4   2021-01-05      -2.5     -12.4 -7.716667  54.291667     35.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.4      -9.0 -5.937500  83.208333     52.0       0.0
# 361 2021-12-28       1.7      -3.1 -0.412500  75.375000     48.0       0.0
# 362 2021-12-29       7.5      -6.8 -0.066667  60.916667     50.0       0.0
# 363 2021-12-30       0.0      -7.9 -4.029167  45.333333     32.0       0.0
# 364 2021-12-31      -2.7      -9.7 -6.575000  42.916667     28.0       0.0
#
#      region_id
# 0      2301066
# 1      2301066
# 2      2301066
# 3      2301066
# 4      2301066
# ..         ...
# 360    2301066
# 361    2301066
# 362    2301066
# 363    2301066
# 364    2301066
#
# [365 rows x 8 columns]
# 영종1동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.3      -8.5 -3.462500  60.291667     42.0       0.0
# 1   2021-01-02      -0.6      -9.4 -5.062500  50.750000     38.0       0.0
# 2   2021-01-03      -0.9      -8.3 -5.170833  50.708333     32.0       0.0
# 3   2021-01-04       0.1      -6.7 -2.279167  62.500000     41.0       0.0
# 4   2021-01-05      -2.5     -12.4 -7.716667  54.291667     35.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.4      -9.0 -5.937500  83.208333     52.0       0.0
# 361 2021-12-28       1.7      -3.1 -0.412500  75.375000     48.0       0.0
# 362 2021-12-29       7.5      -6.8 -0.066667  60.916667     50.0       0.0
# 363 2021-12-30       0.0      -7.9 -4.029167  45.333333     32.0       0.0
# 364 2021-12-31      -2.7      -9.7 -6.575000  42.916667     28.0       0.0
#
#      region_id
# 0      2301064
# 1      2301064
# 2      2301064
# 3      2301064
# 4      2301064
# ..         ...
# 360    2301064
# 361    2301064
# 362    2301064
# 363    2301064
# 364    2301064
#
# [365 rows x 8 columns]
# 운서동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.3      -6.5 -2.775000  60.708333     40.0       0.0
# 1   2021-01-02      -2.3      -7.5 -4.225000  48.875000     43.0       0.0
# 2   2021-01-03      -2.3      -6.7 -4.212500  48.041667     36.0       0.0
# 3   2021-01-04      -0.1      -4.8 -2.016667  61.375000     38.0       0.0
# 4   2021-01-05      -4.1     -11.1 -7.000000  55.291667     37.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -2.2      -5.5 -3.920833  86.666667     62.0       0.0
# 361 2021-12-28       2.2      -1.9  0.420833  82.916667     66.0       0.0
# 362 2021-12-29       6.7      -3.8  0.679167  57.583333     41.0       0.0
# 363 2021-12-30      -1.1      -6.5 -3.495833  45.958333     30.0       0.0
# 364 2021-12-31      -4.2      -8.4 -5.875000  43.833333     34.0       0.0
#
#      region_id
# 0      2301063
# 1      2301063
# 2      2301063
# 3      2301063
# 4      2301063
# ..         ...
# 360    2301063
# 361    2301063
# 362    2301063
# 363    2301063
# 364    2301063
#
# [365 rows x 8 columns]
# 용유동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302051
# 1      2302051
# 2      2302051
# 3      2302051
# 4      2302051
# ..         ...
# 360    2302051
# 361    2302051
# 362    2302051
# 363    2302051
# 364    2302051
#
# [365 rows x 8 columns]
# 만석동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302052
# 1      2302052
# 2      2302052
# 3      2302052
# 4      2302052
# ..         ...
# 360    2302052
# 361    2302052
# 362    2302052
# 363    2302052
# 364    2302052
#
# [365 rows x 8 columns]
# 화수1·화평동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302053
# 1      2302053
# 2      2302053
# 3      2302053
# 4      2302053
# ..         ...
# 360    2302053
# 361    2302053
# 362    2302053
# 363    2302053
# 364    2302053
#
# [365 rows x 8 columns]
# 화수2동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302055
# 1      2302055
# 2      2302055
# 3      2302055
# 4      2302055
# ..         ...
# 360    2302055
# 361    2302055
# 362    2302055
# 363    2302055
# 364    2302055
#
# [365 rows x 8 columns]
# 송현1·2동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302057
# 1      2302057
# 2      2302057
# 3      2302057
# 4      2302057
# ..         ...
# 360    2302057
# 361    2302057
# 362    2302057
# 363    2302057
# 364    2302057
#
# [365 rows x 8 columns]
# 송현3동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302058
# 1      2302058
# 2      2302058
# 3      2302058
# 4      2302058
# ..         ...
# 360    2302058
# 361    2302058
# 362    2302058
# 363    2302058
# 364    2302058
#
# [365 rows x 8 columns]
# 송림1동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302059
# 1      2302059
# 2      2302059
# 3      2302059
# 4      2302059
# ..         ...
# 360    2302059
# 361    2302059
# 362    2302059
# 363    2302059
# 364    2302059
#
# [365 rows x 8 columns]
# 송림2동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302060
# 1      2302060
# 2      2302060
# 3      2302060
# 4      2302060
# ..         ...
# 360    2302060
# 361    2302060
# 362    2302060
# 363    2302060
# 364    2302060
#
# [365 rows x 8 columns]
# 송림3·5동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302061
# 1      2302061
# 2      2302061
# 3      2302061
# 4      2302061
# ..         ...
# 360    2302061
# 361    2302061
# 362    2302061
# 363    2302061
# 364    2302061
#
# [365 rows x 8 columns]
# 송림4동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302063
# 1      2302063
# 2      2302063
# 3      2302063
# 4      2302063
# ..         ...
# 360    2302063
# 361    2302063
# 362    2302063
# 363    2302063
# 364    2302063
#
# [365 rows x 8 columns]
# 송림6동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2302064
# 1      2302064
# 2      2302064
# 3      2302064
# 4      2302064
# ..         ...
# 360    2302064
# 361    2302064
# 362    2302064
# 363    2302064
# 364    2302064
#
# [365 rows x 8 columns]
# 금창동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2309052
# 1      2309052
# 2      2309052
# 3      2309052
# 4      2309052
# ..         ...
# 360    2309052
# 361    2309052
# 362    2309052
# 363    2309052
# 364    2309052
#
# [365 rows x 8 columns]
# 숭의2동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2309075
# 1      2309075
# 2      2309075
# 3      2309075
# 4      2309075
# ..         ...
# 360    2309075
# 361    2309075
# 362    2309075
# 363    2309075
# 364    2309075
#
# [365 rows x 8 columns]
# 숭의1·3동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2309054
# 1      2309054
# 2      2309054
# 3      2309054
# 4      2309054
# ..         ...
# 360    2309054
# 361    2309054
# 362    2309054
# 363    2309054
# 364    2309054
#
# [365 rows x 8 columns]
# 숭의4동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2309076
# 1      2309076
# 2      2309076
# 3      2309076
# 4      2309076
# ..         ...
# 360    2309076
# 361    2309076
# 362    2309076
# 363    2309076
# 364    2309076
#
# [365 rows x 8 columns]
# 용현1·4동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2309056
# 1      2309056
# 2      2309056
# 3      2309056
# 4      2309056
# ..         ...
# 360    2309056
# 361    2309056
# 362    2309056
# 363    2309056
# 364    2309056
#
# [365 rows x 8 columns]
# 용현2동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2309057
# 1      2309057
# 2      2309057
# 3      2309057
# 4      2309057
# ..         ...
# 360    2309057
# 361    2309057
# 362    2309057
# 363    2309057
# 364    2309057
#
# [365 rows x 8 columns]
# 용현3동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2309059
# 1      2309059
# 2      2309059
# 3      2309059
# 4      2309059
# ..         ...
# 360    2309059
# 361    2309059
# 362    2309059
# 363    2309059
# 364    2309059
#
# [365 rows x 8 columns]
# 용현5동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2309060
# 1      2309060
# 2      2309060
# 3      2309060
# 4      2309060
# ..         ...
# 360    2309060
# 361    2309060
# 362    2309060
# 363    2309060
# 364    2309060
#
# [365 rows x 8 columns]
# 학익1동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309061
# 1      2309061
# 2      2309061
# 3      2309061
# 4      2309061
# ..         ...
# 360    2309061
# 361    2309061
# 362    2309061
# 363    2309061
# 364    2309061
#
# [365 rows x 8 columns]
# 학익2동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309062
# 1      2309062
# 2      2309062
# 3      2309062
# 4      2309062
# ..         ...
# 360    2309062
# 361    2309062
# 362    2309062
# 363    2309062
# 364    2309062
#
# [365 rows x 8 columns]
# 도화1동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2309077
# 1      2309077
# 2      2309077
# 3      2309077
# 4      2309077
# ..         ...
# 360    2309077
# 361    2309077
# 362    2309077
# 363    2309077
# 364    2309077
#
# [365 rows x 8 columns]
# 도화2·3동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309065
# 1      2309065
# 2      2309065
# 3      2309065
# 4      2309065
# ..         ...
# 360    2309065
# 361    2309065
# 362    2309065
# 363    2309065
# 364    2309065
#
# [365 rows x 8 columns]
# 주안1동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309066
# 1      2309066
# 2      2309066
# 3      2309066
# 4      2309066
# ..         ...
# 360    2309066
# 361    2309066
# 362    2309066
# 363    2309066
# 364    2309066
#
# [365 rows x 8 columns]
# 주안2동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309067
# 1      2309067
# 2      2309067
# 3      2309067
# 4      2309067
# ..         ...
# 360    2309067
# 361    2309067
# 362    2309067
# 363    2309067
# 364    2309067
#
# [365 rows x 8 columns]
# 주안3동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309068
# 1      2309068
# 2      2309068
# 3      2309068
# 4      2309068
# ..         ...
# 360    2309068
# 361    2309068
# 362    2309068
# 363    2309068
# 364    2309068
#
# [365 rows x 8 columns]
# 주안4동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309069
# 1      2309069
# 2      2309069
# 3      2309069
# 4      2309069
# ..         ...
# 360    2309069
# 361    2309069
# 362    2309069
# 363    2309069
# 364    2309069
#
# [365 rows x 8 columns]
# 주안5동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309070
# 1      2309070
# 2      2309070
# 3      2309070
# 4      2309070
# ..         ...
# 360    2309070
# 361    2309070
# 362    2309070
# 363    2309070
# 364    2309070
#
# [365 rows x 8 columns]
# 주안6동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309071
# 1      2309071
# 2      2309071
# 3      2309071
# 4      2309071
# ..         ...
# 360    2309071
# 361    2309071
# 362    2309071
# 363    2309071
# 364    2309071
#
# [365 rows x 8 columns]
# 주안7동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309072
# 1      2309072
# 2      2309072
# 3      2309072
# 4      2309072
# ..         ...
# 360    2309072
# 361    2309072
# 362    2309072
# 363    2309072
# 364    2309072
#
# [365 rows x 8 columns]
# 주안8동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309073
# 1      2309073
# 2      2309073
# 3      2309073
# 4      2309073
# ..         ...
# 360    2309073
# 361    2309073
# 362    2309073
# 363    2309073
# 364    2309073
#
# [365 rows x 8 columns]
# 관교동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       0.7      -9.3 -3.383333  56.000000     30.0       0.0
# 1   2021-01-02      -1.8     -10.6 -5.700000  49.916667     32.0       0.0
# 2   2021-01-03      -0.7      -8.2 -4.845833  37.000000     28.0       0.0
# 3   2021-01-04       0.2      -5.6 -2.062500  57.958333     33.0       0.0
# 4   2021-01-05      -3.2     -13.1 -7.791667  49.250000     27.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.8     -10.2 -7.291667  79.500000     40.0       0.0
# 361 2021-12-28       1.6      -5.9 -2.100000  78.666667     49.0       0.0
# 362 2021-12-29       6.6      -8.2 -0.404167  65.458333     48.0       0.0
# 363 2021-12-30      -0.7      -8.2 -4.045833  44.458333     31.0       0.0
# 364 2021-12-31      -3.9     -11.8 -7.445833  46.000000     28.0       0.0
#
#      region_id
# 0      2309074
# 1      2309074
# 2      2309074
# 3      2309074
# 4      2309074
# ..         ...
# 360    2309074
# 361    2309074
# 362    2309074
# 363    2309074
# 364    2309074
#
# [365 rows x 8 columns]
# 문학동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2304051
# 1      2304051
# 2      2304051
# 3      2304051
# 4      2304051
# ..         ...
# 360    2304051
# 361    2304051
# 362    2304051
# 363    2304051
# 364    2304051
#
# [365 rows x 8 columns]
# 옥련1동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.2      -7.3 -2.950000  48.125000     29.0       0.0
# 1   2021-01-02      -2.2      -7.5 -4.833333  42.208333     31.0       0.0
# 2   2021-01-03      -2.1      -6.5 -4.600000  36.375000     25.0       0.0
# 3   2021-01-04       0.2      -6.0 -2.204167  55.500000     33.0       0.0
# 4   2021-01-05      -4.1     -10.4 -7.462500  44.291667     29.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -4.1      -5.9 -4.883333  73.000000     43.0       0.0
# 361 2021-12-28       1.0      -2.0 -0.170833  69.000000     49.0       0.0
# 362 2021-12-29       6.0      -5.5 -0.195833  61.000000     51.0       0.0
# 363 2021-12-30      -1.3      -7.8 -4.279167  44.000000     31.0       0.0
# 364 2021-12-31      -4.5      -7.9 -6.458333  37.583333     28.0       0.0
#
#      region_id
# 0      2304060
# 1      2304060
# 2      2304060
# 3      2304060
# 4      2304060
# ..         ...
# 360    2304060
# 361    2304060
# 362    2304060
# 363    2304060
# 364    2304060
#
# [365 rows x 8 columns]
# 옥련2동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.5      -6.2 -2.687500  60.166667     35.0       0.0
# 1   2021-01-02      -1.4      -8.4 -4.470833  50.708333     28.0       0.0
# 2   2021-01-03      -1.3      -8.2 -4.766667  58.166667     27.0       0.0
# 3   2021-01-04       0.4      -5.1 -1.645833  58.083333     35.0       0.0
# 4   2021-01-05      -2.9     -11.3 -6.958333  51.291667     25.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.3      -7.9 -5.662500  75.291667     43.0       0.0
# 361 2021-12-28       1.6      -3.4 -0.566667  71.000000     49.0       0.0
# 362 2021-12-29       7.0      -5.0  0.550000  57.166667     45.0       0.0
# 363 2021-12-30      -0.7      -7.1 -3.604167  42.916667     27.0       0.0
# 364 2021-12-31      -3.8      -9.2 -6.458333  39.541667     27.0       0.0
#
#      region_id
# 0      2304052
# 1      2304052
# 2      2304052
# 3      2304052
# 4      2304052
# ..         ...
# 360    2304052
# 361    2304052
# 362    2304052
# 363    2304052
# 364    2304052
#
# [365 rows x 8 columns]
# 선학동_3일_날씨_202101_202112.csv 저장 완료!
#           date  temp_max  temp_min  temp_avg    hum_avg  hum_min  aqua_sum  \
# 0   2021-01-01       1.5      -6.2 -2.687500  60.166667     35.0       0.0
# 1   2021-01-02      -1.4      -8.4 -4.470833  50.708333     28.0       0.0
# 2   2021-01-03      -1.3      -8.2 -4.766667  58.166667     27.0       0.0
# 3   2021-01-04       0.4      -5.1 -1.645833  58.083333     35.0       0.0
# 4   2021-01-05      -2.9     -11.3 -6.958333  51.291667     25.0       0.0
# ..         ...       ...       ...       ...        ...      ...       ...
# 360 2021-12-27      -3.3      -7.9 -5.662500  75.291667     43.0       0.0
# 361 2021-12-28       1.6      -3.4 -0.566667  71.000000     49.0       0.0
# 362 2021-12-29       7.0      -5.0  0.550000  57.166667     45.0       0.0
# 363 2021-12-30      -0.7      -7.1 -3.604167  42.916667     27.0       0.0
# 364 2021-12-31      -3.8      -9.2 -6.458333  39.541667     27.0       0.0
#
#      region_id
# 0      2304053
# 1      2304053
# 2      2304053
# 3      2304053
# 4      2304053
# ..         ...
# 360    2304053
# 361    2304053
# 362    2304053
# 363    2304053
# 364    2304053
#
# [365 rows x 8 columns]
# 연수1동_3일_날씨_202101_202112.csv 저장 완료!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
#       1 for idx, dong in enumerate(dong_list):
# ----> 2     dong_pd = pd.read_csv('data/wheather_hour/%s_시간별날씨_202101_202112.csv'%dong)
#       3     # print(dong_pd[dong_pd['wind_speed']==-1],'\n===============================================================================')
#       4
#       5     # dong_pd['precipitation'].value_counts()
#    (...)
#       9
#      10     # dong_pd[dong_pd['humidity']==-1]
#      12     idxs = dong_pd[dong_pd['wind_speed']==-1].index
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/wheather_hour/연수2동_시간별날씨_202101_202112.csv'

# %%
for idx, dong in enumerate(dong_list):
    dong_pd = pd.read_csv('data/weather_day/%s_일일_날씨_202101_202112.csv'%dong)
    aqua_3d_list=[]
    for _idx, _dong in dong_pd.iterrows():
        if _idx-3<0:
            aqua_3d_list.append(0.0)
            continue
        else:
            aqua_3d_list.append(dong_pd.iloc[_idx-3:_idx,6].sum())

    dong_pd['aqua_3d']=aqua_3d_list
    
    
    file_name='data/weather_3day/%s_3일간_날씨_202101_202112.csv'%str(dong)
    dong_pd.to_csv(file_name,index=False,float_format='%.2f')
    print('%s_3일간_날씨_202101_202112.csv 저장 완료!'%dong)
# Out:
# 연안동_3일간_날씨_202101_202112.csv 저장 완료!
# 신포동_3일간_날씨_202101_202112.csv 저장 완료!
# 신흥동_3일간_날씨_202101_202112.csv 저장 완료!
# 도원동_3일간_날씨_202101_202112.csv 저장 완료!
# 율목동_3일간_날씨_202101_202112.csv 저장 완료!
# 동인천동_3일간_날씨_202101_202112.csv 저장 완료!
# 개항동_3일간_날씨_202101_202112.csv 저장 완료!
# 영종동_3일간_날씨_202101_202112.csv 저장 완료!
# 영종1동_3일간_날씨_202101_202112.csv 저장 완료!
# 운서동_3일간_날씨_202101_202112.csv 저장 완료!
# 용유동_3일간_날씨_202101_202112.csv 저장 완료!
# 만석동_3일간_날씨_202101_202112.csv 저장 완료!
# 화수1·화평동_3일간_날씨_202101_202112.csv 저장 완료!
# 화수2동_3일간_날씨_202101_202112.csv 저장 완료!
# 송현1·2동_3일간_날씨_202101_202112.csv 저장 완료!
# 송현3동_3일간_날씨_202101_202112.csv 저장 완료!
# 송림1동_3일간_날씨_202101_202112.csv 저장 완료!
# 송림2동_3일간_날씨_202101_202112.csv 저장 완료!
# 송림3·5동_3일간_날씨_202101_202112.csv 저장 완료!
# 송림4동_3일간_날씨_202101_202112.csv 저장 완료!
# 송림6동_3일간_날씨_202101_202112.csv 저장 완료!
# 금창동_3일간_날씨_202101_202112.csv 저장 완료!
# 숭의2동_3일간_날씨_202101_202112.csv 저장 완료!
# 숭의1·3동_3일간_날씨_202101_202112.csv 저장 완료!
# 숭의4동_3일간_날씨_202101_202112.csv 저장 완료!
# 용현1·4동_3일간_날씨_202101_202112.csv 저장 완료!
# 용현2동_3일간_날씨_202101_202112.csv 저장 완료!
# 용현3동_3일간_날씨_202101_202112.csv 저장 완료!
# 용현5동_3일간_날씨_202101_202112.csv 저장 완료!
# 학익1동_3일간_날씨_202101_202112.csv 저장 완료!
# 학익2동_3일간_날씨_202101_202112.csv 저장 완료!
# 도화1동_3일간_날씨_202101_202112.csv 저장 완료!
# 도화2·3동_3일간_날씨_202101_202112.csv 저장 완료!
# 주안1동_3일간_날씨_202101_202112.csv 저장 완료!
# 주안2동_3일간_날씨_202101_202112.csv 저장 완료!
# 주안3동_3일간_날씨_202101_202112.csv 저장 완료!
# 주안4동_3일간_날씨_202101_202112.csv 저장 완료!
# 주안5동_3일간_날씨_202101_202112.csv 저장 완료!
# 주안6동_3일간_날씨_202101_202112.csv 저장 완료!
# 주안7동_3일간_날씨_202101_202112.csv 저장 완료!
# 주안8동_3일간_날씨_202101_202112.csv 저장 완료!
# 관교동_3일간_날씨_202101_202112.csv 저장 완료!
# 문학동_3일간_날씨_202101_202112.csv 저장 완료!
# 옥련1동_3일간_날씨_202101_202112.csv 저장 완료!
# 옥련2동_3일간_날씨_202101_202112.csv 저장 완료!
# 선학동_3일간_날씨_202101_202112.csv 저장 완료!
# 연수1동_3일간_날씨_202101_202112.csv 저장 완료!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
#       1 for idx, dong in enumerate(dong_list):
# ----> 2     dong_pd = pd.read_csv('data/weather_day/%s_일일_날씨_202101_202112.csv'%dong)
#       3     aqua_3d_list=[]
#       4     for _idx, _dong in dong_pd.iterrows():
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/weather_day/연수2동_일일_날씨_202101_202112.csv'
