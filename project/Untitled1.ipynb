# %%
import pandas as pd
city = pd.read_csv('data/incheon_city.csv')
dong_list = list(city.iloc[:]['dong'])

dong_list
# Out:
# ['연안동',
#  '신포동',
#  '신흥동',
#  '도원동',
#  '율목동',
#  '동인천동',
#  '개항동',
#  '영종동',
#  '영종1동',
#  '운서동',
#  '용유동',
#  '만석동',
#  '화수1.화평동',
#  '화수2동',
#  '송현1.2동',
#  '송현3동',
#  '송림1동',
#  '송림2동',
#  '송림3.5동',
#  '송림4동',
#  '송림6동',
#  '금창동',
#  '숭의2동',
#  '숭의1.3동',
#  '숭의4동',
#  '용현1.4동',
#  '용현2동',
#  '용현3동',
#  '용현5동',
#  '학익1동',
#  '학익2동',
#  '도화1동',
#  '도화2.3동',
#  '주안1동',
#  '주안2동',
#  '주안3동',
#  '주안4동',
#  '주안5동',
#  '주안6동',
#  '주안7동',
#  '주안8동',
#  '관교동',
#  '문학동',
#  '옥련1동',
#  '옥련2동',
#  '선학동',
#  '연수1동',
#  '연수2동',
#  '연수3동',
#  '청학동',
#  '동춘1동',
#  '동춘2동',
#  '동춘3동',
#  '송도1동',
#  '송도2동',
#  '송도3동',
#  '송도4동',
#  '송도5동',
#  '구월1동',
#  '구월2동',
#  '구월3동',
#  '구월4동',
#  '간석1동',
#  '간석2동',
#  '간석3동',
#  '간석4동',
#  '만수1동',
#  '만수2동',
#  '만수3동',
#  '만수4동',
#  '만수5동',
#  '만수6동',
#  '장수서창동',
#  '서창2동',
#  '남촌도림동',
#  '논현1동',
#  '논현2동',
#  '논현고잔동',
#  '부평1동',
#  '부평2동',
#  '부평3동',
#  '부평4동',
#  '부평5동',
#  '부평6동',
#  '산곡1동',
#  '산곡2동',
#  '산곡3동',
#  '산곡4동',
#  '청천1동',
#  '청천2동',
# ...

# %%
print(dong_list.index('.'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 print(dong_list.index('.'))
#
# ValueError: '.' is not in list
