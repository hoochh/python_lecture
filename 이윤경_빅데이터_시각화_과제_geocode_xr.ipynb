# %% [markdown]
# # 이윤경_빅데이터 과제
# ## 카페 지도 클러스터링

# %% [markdown]
# ### <데이터 모델링>

# %%
import numpy as np
import pandas as pd
import folium
from folium import plugins
print(folium.__version__)
# Out:
# 0.12.1.post1

# %%
cb_df1=pd.read_csv('data/cb_geocode1.shp.csv', encoding='CP949')
cb_df1=cb_df1.iloc[:,1:]
cb_df1
# Out:
#        store                          address         phone  \
# 0    학동역 DT점             서울시 강남구 학동로 211 1층    02-3444-9973
# 1        수서점       서울시 강남구 광평로 280 수서동 724호    02-3412-2326
# 2       차병원점        서울시 강남구 논현로 566 강남차병원1층     02-538-7615
# 3      강남대로점            서울시 서초구 강남대로 369 1층     02-588-5778
# 4      메가박스점       서울 강남구 삼성동 159 코엑스몰 지하2층    02-6002-3320
# ..       ...                              ...           ...
# 95      수유역점  서울시 강북구 도봉로 352 효성네오인텔리안 101호     02-906-5571
# 96     뉴압구정점    서울시 강남구 논현로 167길 9 낙산프라자 1층     02-545-3181
# 97    디큐브시티점       서울시 구로구 경인로 662 디큐브시티 4층    02-2210-9484
# 98      삼청동점                서울시 종로구 삼청로 109     02-730-5177
# 99  충무로극동빌딩점        서울시 중구 퇴계로 173 남산스퀘어 1층    02-2273-3181
#
#                            address2                            addr3  \
# 0              서울특별시 강남구 학동로 211 1층             서울특별시 강남구 학동로 211 1층
# 1        서울특별시 강남구 광평로 280 수서동 724호       서울특별시 강남구 광평로 280 수서동 724호
# 2         서울특별시 강남구 논현로 566 강남차병원1층        서울특별시 강남구 논현로 566 강남차병원1층
# 3             서울특별시 서초구 강남대로 369 1층            서울특별시 서초구 강남대로 369 1층
# 4       서울특별시 강남구 삼성동 159 코엑스몰 지하2층      서울특별시 강남구 삼성동 159 코엑스몰 지하2층
# ..                              ...                              ...
# 95  서울특별시 강북구 도봉로 352 효성네오인텔리안 101호  서울특별시 강북구 도봉로 352 효성네오인텔리안 101호
# 96    서울특별시 강남구 논현로 167길 9 낙산프라자 1층    서울특별시 강남구 논현로 167길 9 낙산프라자 1층
# 97       서울특별시 구로구 경인로 662 디큐브시티 4층       서울특별시 구로구 경인로 662 디큐브시티 4층
# 98                서울특별시 종로구 삼청로 109                서울특별시 종로구 삼청로 109
# 99        서울특별시 중구 퇴계로 173 남산스퀘어 1층        서울특별시 중구 퇴계로 173 남산스퀘어 1층
#
#             경도         위도   상태
# 0   127.032052  37.514678  정좌표
# 1   127.103108  37.487319  정좌표
# 2   127.034824  37.506440  정좌표
# 3   127.028217  37.495661  정좌표
# 4   127.058795  37.512512  정좌표
# ..         ...        ...  ...
# 95  127.027033  37.638676  정좌표
# 96  127.027427  37.524421  정좌표
# 97  126.888214  37.508124  정좌표
# 98  126.981775  37.585134  정좌표
# 99  126.991059  37.561826  정좌표
#
# [100 rows x 8 columns]

# %%
cb_df2=pd.read_csv('data/cb_geocode2.shp.csv', encoding='CP949')
cb_df2=cb_df2.iloc[:,1:]
cb_df2
# Out:
#          store                                            address  \
# 0    현대자동차여의도점                             서울시 영등포구 국제금융로 20 1층
# 1      포스코사거리점                                 서울시 강남구 테헤란로 439
# 2      선릉로93길점                         서울시 강남구 선릉로93길 6(역삼동) 1층
# 3     강남역먹자골목점                    서울시 강남구 테헤란로1길 29 1층일부 및 2.3층
# 4         삼성로점                            서울시 강남구 삼성로 551 1층,2층
# ..         ...                                                ...
# 95       부천상동점                         경기도 부천시 길주로 111 센타플라자 1층
# 96      안양1번가점                  경기도 안양시 만안구 안양로304번길 12 세진빌딩 2층
# 97    원주AK플라자점                         강원도 원주시 봉화로1 AK플라자원주점 1층
# 98  송파파크하비오B1점  서울특별시 송파구 송파대로 111, 송파 파크하비오 하비오길 극장로 203동 지하1층
# 99     화정중앙공원점        경기도 고양시 덕양구 화신로260번길 26 동민프라자 1층 103~107호
#
#            phone                                         address2  \
# 0    02-783-3391                           서울특별시 영등포구 국제금융로 20 1층
# 1   02-508-7522                                서울특별시 강남구 테헤란로 439
# 2    02-552-3177                       서울특별시 강남구 선릉로93길 6(역삼동) 1층
# 3    02-552-6311                  서울특별시 강남구 테헤란로1길 29 1층일부 및 2.3층
# 4   02-552-9311                           서울특별시 강남구 삼성로 551 1층,2층
# ..           ...                                              ...
# 95  032-329-9471                         경기도 부천시 길주로 111 센타플라자 1층
# 96  031-468-9096                  경기도 안양시 만안구 안양로304번길 12 세진빌딩 2층
# 97  033-748-0631                         강원도 원주시 봉화로1 AK플라자원주점 1층
# 98   02-449-6797  서울특별시 송파구 송파대로 111, 송파 파크하비오 하비오길 극장로 203동 지하1층
# 99  031-979-9402        경기도 고양시 덕양구 화신로260번길 26 동민프라자 1층 103~107호
#
#                                               addr3          경도         위도  \
# 0                            서울특별시 영등포구 국제금융로 20 1층  126.927297  37.524887
# 1                                서울특별시 강남구 테헤란로 439  127.055187  37.506829
# 2                        서울특별시 강남구 선릉로93길 6(역삼동) 1층  127.047900  37.505686
# 3                   서울특별시 강남구 테헤란로1길 29 1층일부 및 2.3층  127.027288  37.500107
# 4                           서울특별시 강남구 삼성로 551 1층,2층  127.054150  37.510710
# ..                                              ...         ...        ...
# 95                         경기도 부천시 길주로 111 센타플라자 1층  126.754884  37.506327
# 96                  경기도 안양시 만안구 안양로304번길 12 세진빌딩 2층  126.921930  37.399414
# 97                         강원도 원주시 봉화로1 AK플라자원주점 1층  127.927644  37.345680
# 98  서울특별시 송파구 송파대로 111, 송파 파크하비오 하비오길 극장로 203동 지하1층  127.124005  37.481491
# 99        경기도 고양시 덕양구 화신로260번길 26 동민프라자 1층 103~107호  126.832993  37.631742
#
#      상태
# 0   정좌표
# 1   정좌표
# 2   정좌표
# 3   정좌표
# 4   정좌표
# ..  ...
# 95  정좌표
# 96  정좌표
# 97  정좌표
# 98  정좌표
# 99  정좌표
#
# [100 rows x 8 columns]

# %%
cb_df3=pd.read_csv('data/cb_geocode3.shp.csv', encoding='CP949')
cb_df3=cb_df3.iloc[:,1:]
cb_df3
# Out:
#                store                                           address  \
# 0          강남역12번출구점                           서울특별시 강남구 테헤란로 111 2층
# 1          서초부띠크모나코점                    서울특별시 서초구 서초대로 397 부띠크모나코 1층
# 2           송파파크하비오점      서울특별시 송파구 송파대로 111 송파파크하비오 205동 1층 110-113
# 3          문정역엠스테이트점                서울 송파구 문정동 643-1번지 엠스테이트 B동 지하1층
# 4               상봉역점                            서울특별시 중랑구 망우로 291 1층
# 5          강동경희대병원앞점                       서울특별시 강동구 동남로 885 양지빌딩 1층
# 6               노원역점                         서울시 노원구 노해로 490, 길빌딩 2층
# 7               합정역점                              서울시 마포구 독막로 13, 2층
# 8               종각역점                                서울시 종로구 종로 70 2층
# 9              평택소사점                       경기도 평택시 평남로 862, 로이드빌딩 1층
# 10            몽촌토성역점                       서울시 송파구 방이동 44-2, 장은빌딩 1층
# 11          도곡동지오빌딩점                   서울특별시 강남구 도곡동 543-1, 지오빌딩 B1층
# 12            강북구청앞점  서울특별시 강북구 한천로 139길 25, 1층 일부 및 2층 (수유동 191-70)
# 13        송도트리플스트리트점             인천 연수구 송도과학로 16번길 33-4 D동 119호,207호
# 14          구의삼성쉐르빌점                    서울특별시 광진구 구의강변로 106 삼성쉐르빌 1층
# 15        여의도SK증권빌딩점              서울특별시 영등포구 국제금융로8길31 여의도SK증권빌딩점 1층
# 16       현대시티몰가든파이브점             서울특별시 송파구 충민로 66 가든파이브 라이프동 테크노관 1층
# 17           합정푸르지오점                서울특별시 마포구 월드컵로 3길 14, 푸르지오 2차 1층
# 18         신논현역2번출구점                             서울시 서초구 강남대로 475 2층
# 19         위례2차아이파크점               서울시 송파구 위례광장로 230 위례2차 아이파크 B동 1층
# 20          혜화역1번출구점                            서울특별시 종로구 대학로 128 2층
# 21           한성대입구역점                            서울특별시 성북구 삼선교로 12 1층
# 22         한티역디마크빌딩점                      서울특별시 강남구 도곡로 408 디마크빌딩 1층
# 23        논현201-5번지점                   서울특별시 강남구  강남대로112길 20 1층, 2층
# 24            부산수영역점                            부산광역시 수영구 수영로 667 1층
# 25             부산정관점                         부산광역시 기장군 정관로 563 1층,2층
# 26           수원송죽DT점                            경기도 수원시 장안구 경수대로 989
# 27           동교동삼거리점                          서울특별시 마포구 양화로 196(동교동)
# 28             성남신흥점                       경기도 성남시 수정구 수정로 190 (신흥동)
# 29             응암동점                      서울시 은평구 은평로 121(응암동), 메디컬빌딩
# 30           서수원이마트점           경기도 수원시 권선구 수인로 291(구운동), 이마트 서수원점 1층
# 31            양천향교역점                          서울특별시 강서구 강서로 457(마곡동)
# 32     성균관대 자연과학캠퍼스점       경기 수원시 장안구 서부로 2066, 성균관대 자연과학 캠퍼스 N센터 1층
# 33         마곡마커스빌딩점                       서울특별시 강서구 마곡동로 55 마커스빌딩 1층
# 34          방이역4번출구점                               서울 송파구 방이동 206-11
# 35      IFC MALL 3호점                서울시 영등포구 국제금융로10 IFC Mall L2(2층)
# 36           동탄능동DT점        경기도 화성시 능동 453-4,453-8,454-1 소재 건물(1~3층)
# 37           수원인계DT점                         경기도 수원시 팔달구 인계로79 (인계동)
# 38  인천공항 제2여객터미널 입구점      인천광역시 중구 운서동 2868 인천공항 제2터미널 1층 연번(23-124)
# 39          부산서면서전로점                           부산광역시 부산진구 서전로 12, 1층
# 40         분당차병원본관앞점                       경기도 성남시 분당구 야탑로64 DS타워 1층
# 41          신용산역래미안점                                  서울시 용산구 한강대로95
# 42      선릉역3번출구세방빌딩점                       서울특별시 강남구 선릉로 433 세방빌딩 1층
#
#             phone                                        address2  \
# 0     02-569-5838                           서울특별시 강남구 테헤란로 111 2층
# 1     02-537-4662                    서울특별시 서초구 서초대로 397 부띠크모나코 1층
# 2     02-449-6881      서울특별시 송파구 송파대로 111 송파파크하비오 205동 1층 110-113
# 3    02-6177-9080             서울특별시 송파구 문정동 643-1번지 엠스테이트 B동 지하1층
# 4     02-493-8902                            서울특별시 중랑구 망우로 291 1층
# 5     02-481-9938                       서울특별시 강동구 동남로 885 양지빌딩 1층
# 6     02-952-9577                       서울특별시 노원구 노해로 490, 길빌딩 2층
# 7     02-338-9178                            서울특별시 마포구 독막로 13, 2층
# 8     02-739-6268                              서울특별시 종로구 종로 70 2층
# 9    031-692-2405                       경기도 평택시 평남로 862, 로이드빌딩 1층
# 10   02-2141-0407                     서울특별시 송파구 방이동 44-2, 장은빌딩 1층
# 11   02-2058-3027                   서울특별시 강남구 도곡동 543-1, 지오빌딩 B1층
# 12    02-994-8878  서울특별시 강북구 한천로 139길 25, 1층 일부 및 2층 (수유동 191-70)
# 13   032-310-9644          인천광역시 연수구 송도과학로 16번길 33-4 D동 119호,207호
# 14   02-2201-8953                    서울특별시 광진구 구의강변로 106 삼성쉐르빌 1층
# 15   02-6484-5150              서울특별시 영등포구 국제금융로8길31 여의도SK증권빌딩점 1층
# 16   02-2673-2110             서울특별시 송파구 충민로 66 가든파이브 라이프동 테크노관 1층
# 17    02-338-7684                서울특별시 마포구 월드컵로 3길 14, 푸르지오 2차 1층
# 18    02-541-9650                           서울특별시 서초구 강남대로 475 2층
# 19    02-449-9703             서울특별시 송파구 위례광장로 230 위례2차 아이파크 B동 1층
# 20    02-766-7937                            서울특별시 종로구 대학로 128 2층
# 21    02-766-7951                            서울특별시 성북구 삼선교로 12 1층
# 22   02-2052-6590                      서울특별시 강남구 도곡로 408 디마크빌딩 1층
# 23    02-541-9563                    서울특별시 강남구 강남대로112길 20 1층, 2층
# 24   051-759-9046                            부산광역시 수영구 수영로 667 1층
# 25   051-728-7435                         부산광역시 기장군 정관로 563 1층,2층
# 26   031-248-6086                            경기도 수원시 장안구 경수대로 989
# 27   02-336-9198                           서울특별시 마포구 양화로 196(동교동)
# 28   031-759-6675                       경기도 성남시 수정구 수정로 190 (신흥동)
# 29    02-389-6283                   서울특별시 은평구 은평로 121(응암동), 메디컬빌딩
# 30   031-278-6593           경기도 수원시 권선구 수인로 291(구운동), 이마트 서수원점 1층
# 31   02-3665-9506                          서울특별시 강서구 강서로 457(마곡동)
# 32   031-278-7640      경기도 수원시 장안구 서부로 2066, 성균관대 자연과학 캠퍼스 N센터 1층
# 33   02-6905-3030                      서울특별시 강서구 마곡동로 55 마커스빌딩 1층
# 34    02-420-0386                            서울특별시 송파구 방이동 206-11
# 35   02-6137-5056              서울특별시 영등포구 국제금융로10 IFC Mall L2(2층)
# 36   031-267-4182        경기도 화성시 능동 453-4,453-8,454-1 소재 건물(1~3층)
# 37   031-898-8818                         경기도 수원시 팔달구 인계로79 (인계동)
# 38   032-743-2894      인천광역시 중구 운서동 2868 인천공항 제2터미널 1층 연번(23-124)
# 39   051-819-8708                           부산광역시 부산진구 서전로 12, 1층
# 40  031-8017-8243                       경기도 성남시 분당구 야탑로64 DS타워 1층
# 41   02-2074-1049                                서울특별시 용산구 한강대로95
# 42   02-2051-9328                       서울특별시 강남구 선릉로 433 세방빌딩 1층
#
#                                              addr3          경도         위도  \
# 0                            서울특별시 강남구 테헤란로 111 2층  127.029282  37.498881
# 1                     서울특별시 서초구 서초대로 397 부띠크모나코 1층  127.024516  37.497434
# 2       서울특별시 송파구 송파대로 111 송파파크하비오 205동 1층 110-113  127.124005  37.481491
# 3              서울특별시 송파구 문정동 643-1번지 엠스테이트 B동 지하1층  127.115463  37.481768
# 4                             서울특별시 중랑구 망우로 291 1층  127.084790  37.596445
# 5                        서울특별시 강동구 동남로 885 양지빌딩 1층  127.155977  37.552654
# 6                        서울특별시 노원구 노해로 490, 길빌딩 2층  127.062413  37.654413
# 7                             서울특별시 마포구 독막로 13, 2층  126.915065  37.548813
# 8                               서울특별시 종로구 종로 70 2층  126.985172  37.569915
# 9                        경기도 평택시 평남로 862, 로이드빌딩 1층  127.111502  37.000469
# 10                     서울특별시 송파구 방이동 44-2, 장은빌딩 1층  127.112757  37.516922
# 11                   서울특별시 강남구 도곡동 543-1, 지오빌딩 B1층  127.041651  37.492229
# 12  서울특별시 강북구 한천로 139길 25, 1층 일부 및 2층 (수유동 191-70)  127.025725  37.639095
# 13          인천광역시 연수구 송도과학로 16번길 33-4 D동 119호,207호  126.662842  37.378661
# 14                    서울특별시 광진구 구의강변로 106 삼성쉐르빌 1층  127.094898  37.539858
# 15              서울특별시 영등포구 국제금융로8길31 여의도SK증권빌딩점 1층  126.928067  37.519747
# 16             서울특별시 송파구 충민로 66 가든파이브 라이프동 테크노관 1층  127.124962  37.477615
# 17                서울특별시 마포구 월드컵로 3길 14, 푸르지오 2차 1층  126.912343  37.551036
# 18                           서울특별시 서초구 강남대로 475 2층  127.023860  37.504726
# 19             서울특별시 송파구 위례광장로 230 위례2차 아이파크 B동 1층  127.143402  37.479429
# 20                            서울특별시 종로구 대학로 128 2층  127.002163  37.582714
# 21                            서울특별시 성북구 삼선교로 12 1층  127.007141  37.587589
# 22                      서울특별시 강남구 도곡로 408 디마크빌딩 1층  127.055233  37.496621
# 23                    서울특별시 강남구 강남대로112길 20 1층, 2층  127.026050  37.505508
# 24                            부산광역시 수영구 수영로 667 1층  129.114479  35.165354
# 25                         부산광역시 기장군 정관로 563 1층,2층  129.175634  35.321915
# 26                            경기도 수원시 장안구 경수대로 989  127.002926  37.305078
# 27                          서울특별시 마포구 양화로 196(동교동)  126.926516  37.558375
# 28                       경기도 성남시 수정구 수정로 190 (신흥동)  127.140979  37.443428
# 29                   서울특별시 은평구 은평로 121(응암동), 메디컬빌딩  126.921094  37.600445
# 30           경기도 수원시 권선구 수인로 291(구운동), 이마트 서수원점 1층  126.969825  37.283392
# 31                          서울특별시 강서구 강서로 457(마곡동)  126.840422  37.566243
# 32      경기도 수원시 장안구 서부로 2066, 성균관대 자연과학 캠퍼스 N센터 1층  126.972373  37.292214
# 33                      서울특별시 강서구 마곡동로 55 마커스빌딩 1층  126.833037  37.560067
# 34                            서울특별시 송파구 방이동 206-11  127.125765  37.509345
# 35              서울특별시 영등포구 국제금융로10 IFC Mall L2(2층)  126.924876  37.525177
# 36        경기도 화성시 능동 453-4,453-8,454-1 소재 건물(1~3층)  127.056333  37.210979
# 37                         경기도 수원시 팔달구 인계로79 (인계동)  127.026481  37.268873
# 38      인천광역시 중구 운서동 2868 인천공항 제2터미널 1층 연번(23-124)  126.433631  37.468589
# 39                           부산광역시 부산진구 서전로 12, 1층  129.060872  35.157523
# 40                       경기도 성남시 분당구 야탑로64 DS타워 1층  127.125979  37.409502
# 41                                서울특별시 용산구 한강대로95  126.967287  37.529452
# 42                       서울특별시 강남구 선릉로 433 세방빌딩 1층  127.048916  37.503777
#
#       상태
# 0    정좌표
# 1    정좌표
# 2    정좌표
# 3   인근좌표
# 4    정좌표
# 5    정좌표
# 6    정좌표
# 7    정좌표
# 8    정좌표
# 9    정좌표
# 10   정좌표
# 11   정좌표
# 12   정좌표
# 13   정좌표
# 14   정좌표
# 15   정좌표
# 16   정좌표
# 17   정좌표
# 18   정좌표
# 19   정좌표
# 20   정좌표
# 21   정좌표
# 22   정좌표
# 23   정좌표
# 24   정좌표
# 25   정좌표
# 26   정좌표
# 27   정좌표
# 28   정좌표
# 29   정좌표
# 30   정좌표
# 31   정좌표
# 32   정좌표
# 33   정좌표
# 34   정좌표
# 35   정좌표
# 36   정좌표
# 37   정좌표
# 38   정좌표
# 39   정좌표
# 40   정좌표
# 41   정좌표
# 42   정좌표

# %%
cb_df=pd.concat([cb_df1,cb_df2])
cb_df
# Out:
#          store                                            address  \
# 0      학동역 DT점                               서울시 강남구 학동로 211 1층
# 1          수서점                         서울시 강남구 광평로 280 수서동 724호
# 2         차병원점                          서울시 강남구 논현로 566 강남차병원1층
# 3        강남대로점                              서울시 서초구 강남대로 369 1층
# 4        메가박스점                         서울 강남구 삼성동 159 코엑스몰 지하2층
# ..         ...                                                ...
# 95       부천상동점                         경기도 부천시 길주로 111 센타플라자 1층
# 96      안양1번가점                  경기도 안양시 만안구 안양로304번길 12 세진빌딩 2층
# 97    원주AK플라자점                         강원도 원주시 봉화로1 AK플라자원주점 1층
# 98  송파파크하비오B1점  서울특별시 송파구 송파대로 111, 송파 파크하비오 하비오길 극장로 203동 지하1층
# 99     화정중앙공원점        경기도 고양시 덕양구 화신로260번길 26 동민프라자 1층 103~107호
#
#            phone                                         address2  \
# 0   02-3444-9973                             서울특별시 강남구 학동로 211 1층
# 1   02-3412-2326                       서울특별시 강남구 광평로 280 수서동 724호
# 2    02-538-7615                        서울특별시 강남구 논현로 566 강남차병원1층
# 3    02-588-5778                            서울특별시 서초구 강남대로 369 1층
# 4   02-6002-3320                      서울특별시 강남구 삼성동 159 코엑스몰 지하2층
# ..           ...                                              ...
# 95  032-329-9471                         경기도 부천시 길주로 111 센타플라자 1층
# 96  031-468-9096                  경기도 안양시 만안구 안양로304번길 12 세진빌딩 2층
# 97  033-748-0631                         강원도 원주시 봉화로1 AK플라자원주점 1층
# 98   02-449-6797  서울특별시 송파구 송파대로 111, 송파 파크하비오 하비오길 극장로 203동 지하1층
# 99  031-979-9402        경기도 고양시 덕양구 화신로260번길 26 동민프라자 1층 103~107호
#
#                                               addr3          경도         위도  \
# 0                              서울특별시 강남구 학동로 211 1층  127.032052  37.514678
# 1                        서울특별시 강남구 광평로 280 수서동 724호  127.103108  37.487319
# 2                         서울특별시 강남구 논현로 566 강남차병원1층  127.034824  37.506440
# 3                             서울특별시 서초구 강남대로 369 1층  127.028217  37.495661
# 4                       서울특별시 강남구 삼성동 159 코엑스몰 지하2층  127.058795  37.512512
# ..                                              ...         ...        ...
# 95                         경기도 부천시 길주로 111 센타플라자 1층  126.754884  37.506327
# 96                  경기도 안양시 만안구 안양로304번길 12 세진빌딩 2층  126.921930  37.399414
# 97                         강원도 원주시 봉화로1 AK플라자원주점 1층  127.927644  37.345680
# 98  서울특별시 송파구 송파대로 111, 송파 파크하비오 하비오길 극장로 203동 지하1층  127.124005  37.481491
# 99        경기도 고양시 덕양구 화신로260번길 26 동민프라자 1층 103~107호  126.832993  37.631742
#
#      상태
# 0   정좌표
# 1   정좌표
# 2   정좌표
# 3   정좌표
# 4   정좌표
# ..  ...
# 95  정좌표
# 96  정좌표
# 97  정좌표
# 98  정좌표
# 99  정좌표
#
# [200 rows x 8 columns]

# %%
cb_df=pd.concat([cb_df,cb_df3])
cb_df
# Out:
#                store                                       address  \
# 0            학동역 DT점                          서울시 강남구 학동로 211 1층
# 1                수서점                    서울시 강남구 광평로 280 수서동 724호
# 2               차병원점                     서울시 강남구 논현로 566 강남차병원1층
# 3              강남대로점                         서울시 서초구 강남대로 369 1층
# 4              메가박스점                    서울 강남구 삼성동 159 코엑스몰 지하2층
# ..               ...                                           ...
# 38  인천공항 제2여객터미널 입구점  인천광역시 중구 운서동 2868 인천공항 제2터미널 1층 연번(23-124)
# 39          부산서면서전로점                       부산광역시 부산진구 서전로 12, 1층
# 40         분당차병원본관앞점                   경기도 성남시 분당구 야탑로64 DS타워 1층
# 41          신용산역래미안점                              서울시 용산구 한강대로95
# 42      선릉역3번출구세방빌딩점                   서울특별시 강남구 선릉로 433 세방빌딩 1층
#
#             phone                                    address2  \
# 0    02-3444-9973                        서울특별시 강남구 학동로 211 1층
# 1    02-3412-2326                  서울특별시 강남구 광평로 280 수서동 724호
# 2     02-538-7615                   서울특별시 강남구 논현로 566 강남차병원1층
# 3     02-588-5778                       서울특별시 서초구 강남대로 369 1층
# 4    02-6002-3320                 서울특별시 강남구 삼성동 159 코엑스몰 지하2층
# ..            ...                                         ...
# 38   032-743-2894  인천광역시 중구 운서동 2868 인천공항 제2터미널 1층 연번(23-124)
# 39   051-819-8708                       부산광역시 부산진구 서전로 12, 1층
# 40  031-8017-8243                   경기도 성남시 분당구 야탑로64 DS타워 1층
# 41   02-2074-1049                            서울특별시 용산구 한강대로95
# 42   02-2051-9328                   서울특별시 강남구 선릉로 433 세방빌딩 1층
#
#                                          addr3          경도         위도   상태
# 0                         서울특별시 강남구 학동로 211 1층  127.032052  37.514678  정좌표
# 1                   서울특별시 강남구 광평로 280 수서동 724호  127.103108  37.487319  정좌표
# 2                    서울특별시 강남구 논현로 566 강남차병원1층  127.034824  37.506440  정좌표
# 3                        서울특별시 서초구 강남대로 369 1층  127.028217  37.495661  정좌표
# 4                  서울특별시 강남구 삼성동 159 코엑스몰 지하2층  127.058795  37.512512  정좌표
# ..                                         ...         ...        ...  ...
# 38  인천광역시 중구 운서동 2868 인천공항 제2터미널 1층 연번(23-124)  126.433631  37.468589  정좌표
# 39                       부산광역시 부산진구 서전로 12, 1층  129.060872  35.157523  정좌표
# 40                   경기도 성남시 분당구 야탑로64 DS타워 1층  127.125979  37.409502  정좌표
# 41                            서울특별시 용산구 한강대로95  126.967287  37.529452  정좌표
# 42                   서울특별시 강남구 선릉로 433 세방빌딩 1층  127.048916  37.503777  정좌표
#
# [243 rows x 8 columns]

# %% [markdown]
# ### <지도 클러스터링>

# %%
# 클러스터링 하기

from folium import plugins

map_osm=folium.Map(location=[37.524887,126.927297], zoom_start=10)
location=[]
popup=[]

for i, store in cb_df.iterrows():
    location.append([store['위도'],store['경도']])
    popup.append(store['store'])

plugins.MarkerCluster(location, popup).add_to(map_osm)

map_osm.save('data/lyk_map_cb_clustering.html')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_894257a46313cd35f773c81370646021 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_894257a46313cd35f773c81370646021&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_894257a46313cd35f773c81370646021 = L.map(
#                 &quot;map_894257a46313cd35f773c81370646021&quot;,
#                 {
#                     center: [37.524887, 126.927297],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d10e76bb52a0eaaa979bc94e2f5567c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_894257a46313cd35f773c81370646021);
#
#
#             var marker_cluster_55f914bd9c3dd046fa94629c77329f54 = L.markerClusterGroup(
#                 {}
#             );
#             map_894257a46313cd35f773c81370646021.addLayer(marker_cluster_55f914bd9c3dd046fa94629c77329f54);
#
#
#             var marker_8b8a1c0e36148783b9349f0c344bcae6 = L.marker(
#                 [37.5146783674783, 127.032052480207],
#                 {}
#             ).addTo(marker_cluster_55f914bd9c3dd046fa94629c77329f54);
#
#
#         var popup_b05e191bb904c98fb985956a2ffbda56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7caa0dccf7832bc8725aa510b22b2ffd = $(`&lt;div id=&quot;html_7caa0dccf7832bc8725aa510b22b2ffd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;학동역 DT점&lt;/div&gt;`)[0];
#             popup_b05e191bb904c98fb985956a2ffbda56.setContent(html_7caa0dccf7832bc8725aa510b22b2ffd);
#
#
#         marker_8b8a1c0e36148783b9349f0c344bcae6.bindPopup(popup_b05e191bb904c98fb985956a2ffbda56)
#         ;
#
#
#
#
#             var marker_c36e5a5486e59da343303a56ef241090 = L.marker(
#                 [37.4873186442131, 127.103108075643],
#                 {}
#             ).addTo(marker_cluster_55f914bd9c3dd046fa94629c77329f54);
#
#
#         var popup_159d87b3e7b4c5aed550180739ccf63b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4f2766420e21378119c06a22ba030105 = $(`&lt;div id=&quot;html_4f2766420e21378119c06a22ba030105&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;수서점&lt;/div&gt;`)[0];
#             popup_159d87b3e7b4c5aed550180739ccf63b.setContent(html_4f2766420e21378119c06a22ba030105);
#
#
#         marker_c36e5a5486e59da343303a56ef241090.bindPopup(popup_159d87b3e7b4c5aed550180739ccf63b)
#         ;
#
#
#
#
#             var marker_6f242c6d501f7d3e73983d6ac6d0d02b = L.marker(
#                 [37.5064397339232, 127.034824313484],
#                 {}
#             ).addTo(marker_cluster_55f914bd9c3dd046fa94629c77329f54);
#
#
#         var popup_b94bde2582569f4ebfb5f126a8a8183f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f18c705b6344ca8bf02d61e04bfc6d76 = $(`&lt;div id=&quot;html_f18c705b6344ca8bf02d61e04bfc6d76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;차병원점&lt;/div&gt;`)[0];
#             popup_b94bde2582569f4ebfb5f126a8a8183f.setContent(html_f18c705b6344ca8bf02d61e04bfc6d76);
#
#
#         marker_6f242c6d501f7d3e73983d6ac6d0d02b.bindPopup(popup_b94bde2582569f4ebfb5f126a8a8183f)
#         ;
#
#
#
#
#             var marker_351e9c10b1d56d9e8cead55f8985d5a9 = L.marker(
#                 [37.4956614022321, 127.028216662926],
#                 {}
#             ).addTo(marker_cluster_55f914bd9c3dd046fa94629c77329f54);
#
#
#         var popup_fd2ee5c431a83a0a94b65bbe0ea86347 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e35e5db3c0a91ef2ce84a3c78c506b38 = $(`&lt;div id=&quot;html_e35e5db3c0a91ef2ce84a3c78c506b38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남대로점&lt;/div&gt;`)[0];
#             popup_fd2ee5c431a83a0a94b65bbe0ea86347.setContent(html_e35e5db3c0a91ef2ce84a3c78c506b38);
#
#
#         marker_351e9c10b1d56d9e8cead55f8985d5a9.bindPopup(popup_fd2ee5c431a83a0a94b65bbe0ea86347)
#         ;
#
#
#
#
#             var marker_7e8ccd637f4ca838971e700a5b068c7a = L.marker(
#                 [37.5125118333676, 127.058794970892],
#                 {}
#             ).addTo(marker_cluster_55f914bd9c3dd046fa94629c77329f54);
#
#
#         var popup_aa775e1c77fe00f56ef090e242ab77b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a6c35cfd13fab37b30ab895d0c924cb8 = $(`&lt;div id=&quot;html_a6c35cfd13fab3
