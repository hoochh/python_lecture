# %%
# %matplotlib inline 
#매직 명령어
import numpy as np
import pandas as pd
import matplotlib # plot 그리기 위해 사용
import matplotlib.pyplot as plt # 그림 요소를 만들어 사용하기 위해

# %%
data=np.random.rand(50)
print(type(data))
print(data)
# Out:
# <class 'numpy.ndarray'>
# [0.72187391 0.25854589 0.70678461 0.26453052 0.35697134 0.51669348
#  0.19325179 0.31812211 0.96050564 0.65269687 0.93342139 0.32810132
#  0.53280788 0.58685564 0.83278936 0.53247874 0.75203449 0.32875589
#  0.84005311 0.00403362 0.74716427 0.80149616 0.7531217  0.86594591
#  0.06696349 0.33646244 0.94369532 0.59445894 0.26477829 0.67161131
#  0.63264945 0.99429623 0.53607464 0.29755128 0.23018538 0.04612352
#  0.34639664 0.46665707 0.64468191 0.447765   0.44916245 0.84531164
#  0.86403448 0.37288009 0.89561609 0.2704766  0.61625046 0.93338181
#  0.85009124 0.10329591]

# %%
seri=pd.Series(data)
print(type(seri))
print(seri)
# Out:
# <class 'pandas.core.series.Series'>
# 0     0.721874
# 1     0.258546
# 2     0.706785
# 3     0.264531
# 4     0.356971
# 5     0.516693
# 6     0.193252
# 7     0.318122
# 8     0.960506
# 9     0.652697
# 10    0.933421
# 11    0.328101
# 12    0.532808
# 13    0.586856
# 14    0.832789
# 15    0.532479
# 16    0.752034
# 17    0.328756
# 18    0.840053
# 19    0.004034
# 20    0.747164
# 21    0.801496
# 22    0.753122
# 23    0.865946
# 24    0.066963
# 25    0.336462
# 26    0.943695
# 27    0.594459
# 28    0.264778
# 29    0.671611
# 30    0.632649
# 31    0.994296
# 32    0.536075
# 33    0.297551
# 34    0.230185
# 35    0.046124
# 36    0.346397
# 37    0.466657
# 38    0.644682
# 39    0.447765
# 40    0.449162
# 41    0.845312
# 42    0.864034
# 43    0.372880
# 44    0.895616
# 45    0.270477
# 46    0.616250
# 47    0.933382
# 48    0.850091
# 49    0.103296
# dtype: float64

# %%
seri.plot()
# Out:
# <AxesSubplot:>

# %%
matplotlib.style.use("ggplot") # 그래프 스타일 변경
seri.plot()
# Out:
# <AxesSubplot:>

# %%
# 넘파이 행렬을 10행 3열로 만든 후 판다스의 데이터 프레임으로 변환
data_set=np.random.rand(10,3)
df=pd.DataFrame(data_set,columns=['A','B','C'])
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           A         B         C
# 0  0.162970  0.853530  0.021239
# 1  0.835979  0.991490  0.094464
# 2  0.645155  0.086665  0.170193
# 3  0.616792  0.598797  0.932123
# 4  0.325341  0.077237  0.356945
# 5  0.159027  0.386802  0.959158
# 6  0.498124  0.196723  0.764708
# 7  0.787155  0.989346  0.608455
# 8  0.909324  0.029602  0.242255
# 9  0.936039  0.353013  0.010735

# %%
df.plot() # 라인 그래프로
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar') # 막대 그래프로
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='barh') # 수평 막대 그래프
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area') # 영역형 그래프
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',stacked=False)
# Out:
# <AxesSubplot:>

# %%
seri2=pd.Series(np.random.rand(5), index=['A','B','C','D','E'], name='Series')
seri2.plot(kind='pie', autopct='%.2f', fontsize=16, figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='Series'>

# %%
#매직 명령어
# %matplotlib inline

# %%
df=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
df.plot()
# Out:
# <AxesSubplot:>

# %%
df1=pd.DataFrame(np.random.rand(6,4),
                index=['one','two','three','four','five','six'],
                columns=pd.Index(['가','나','다','라'], name="종류"))
# 한글은 encoding 되지 않음
#plt.rcParams['axes.unicode_minus']=False
df1.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:>
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47448 (\N{HANGUL SYLLABLE RYU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
from matplotlib import rc, font_manager
# 한글 처리를 위해 폰트 설정
fontname="C:/Windows/Fonts/gulim.ttc"
font_name=font_manager.FontProperties(fname=fontname).get_name()

rc('font',family=font_name)
df2=pd.DataFrame(np.random.rand(6,4),
                index=['one','two','three','four','five','six'],
                columns=pd.Index(['가','나','다','라'], name="종류"))

#plt.rcParams['axes.unicode_minus']=False 
#축에 마이너스 값이 있을 때 음수 부호가 깨지지 않고 표시
df1.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:>

# %%
s3=pd.Series(np.random.normal(0,100,size=200)) #np.random.normal(평균,표준편차,size)
s3.head()
# Out:
# 0     31.121448
# 1    -59.939073
# 2     -4.337368
# 3   -228.240690
# 4     -6.491594
# dtype: float64

# %%
#축에 마이너스 값이 있을 때 음수 부호가 깨지지 않고 표시
#plt.rcParams['axes.unicode_minus']=False 
s3.hist()
# Out:
# <AxesSubplot:>

# %%
# 축 구간은 기본값으로 50개로 설정됨
s3.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#scatter
#산점도 : 서로 다른 독립변수 x1, x2의 관계를 파악할 때 사용
#normal(mu,sigma,size=(rows,cols))
#mu:중앙값, sigma:표준편차
x1=np.random.normal(1,1,size=(100,1))
x2=np.random.normal(-2,4,size=(100,1))
#concatenate : 열방향 연결, axis=1 라고 방향, axis=0 세로 방향
x=np.concatenate((x1,x2),axis=1)
#첫 5행 출력
print(x[:5])
# Out:
# [[ 0.99578772 -0.25392414]
#  [ 1.12146953 -3.65768403]
#  [ 1.76666182 -7.12631836]
#  [ 1.59373291 -3.6988144 ]
#  [ 0.25791539  2.17307791]]

# %%
df3=pd.DataFrame(x,columns=["x1","x2"])
df3.head()
# Out:
#          x1        x2
# 0  0.995788 -0.253924
# 1  1.121470 -3.657684
# 2  1.766662 -7.126318
# 3  1.593733 -3.698814
# 4  0.257915  2.173078

# %%
# x1과  x2의  상관관계 # x1(x축), x2(y축)
# 양의 상관관계 : 산점도가 좌측하단에서 우측 상단으로 
# 음의 상관관계 : 산점도가 좌측상단에서 우측하단으로
plt.scatter(df3["x1"],df3["x2"]) # 이 그래프에서 상관관계를 찾을 수 없음

# %%
x=np.array([1,2,3,4,5])
y=np.array([10,20,20,30,40])
data={'x':x,'y':y}
df=pd.DataFrame(data)
df
# Out:
#    x   y
# 0  1  10
# 1  2  20
# 2  3  20
# 3  4  30
# 4  5  40

# %%
print(df.x.corr(df.y))
plt.scatter(df["x"],df["y"])
# Out:
# 0.970725343394151
